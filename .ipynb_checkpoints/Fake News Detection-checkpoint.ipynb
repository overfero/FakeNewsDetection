# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
import string
import re
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import graphviz
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
raw = pd.read_csv('Scrapping.csv',encoding_errors='ignore',sep=';')
raw1 = pd.read_csv('500_berita_indonesia.csv',encoding_errors='ignore',sep=';')
raw2 = pd.read_csv("600 news with valid hoax label.csv",encoding_errors='ignore',sep=';')
barun = pd.read_csv('hoax.csv')
benan = pd.read_csv('fact.csv')
detik = pd.read_csv('fact_detik.csv')

# %%
raw.head()
# Out:
#    Label                                           Headline  \
# 0      1  Pertamina dan Pemerintah Kalrifikasi Isu BBM N...
# 1      1  Polda Nusa Tenggara Barat Mengklarifkasi Bahwa...
# 2      1  PT Ultrajaya Milk Industry Tbk Mengklarifikasi...
# 3      1  BBKSDA Jatim Mengklarifikasi Bahwa Wisata Alam...
# 4      1  BMKG Mataram Menghimbau Agar Warga Tidak Langs...
#
#                                                 Body  Unnamed: 3  Unnamed: 4  \
# 0  Foto: Kumparan.com Debunk ini berisi iKlarifik...         NaN         NaN
# 1  Foto Ilustrasi Perkosaan Debunk ini berisi kla...         NaN         NaN
# 2  Debunk ini berisi klarifikasi dari PT Ultrajay...         NaN         NaN
# 3  foto: tribunnews.com Debunk ini berisi Klrifik...         NaN         NaN
# 4  Foto: tribunnews.com (Jokowi sedang memantau l...         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
raw1.head()
# Out:
#   kategori                                             berita
# 0    valid  "Gunung Agung erupsi untuk pertama kali pada 2...
# 1    valid  "Jakarta, CNN Indonesia -- Menteri BUMN Erick ...
# 2    valid  "Dosen Fakultas Kedokteran Hewan IPB, Yusuf Ri...
# 3    valid  "Jakarta - Dua anggota TNI, Serda N dan Serda ...
# 4    valid  "Akui Tembak Jatuh Pesawat Ukraina, Iran Tuai ...

# %%
raw2.head()
# Out:
#                                               berita tagging
# 0  Jakarta, Di jejaring sosial, banyak beredar in...   Valid
# 1  Isu bahwa ikan lele mengandung sel kanker di j...   Valid
# 2  Bagi penikmat kuliner dengan bahan dasar ikan ...   Valid
# 3  Ikan lele merupakan salah satu makanan favorit...   Valid
# 4  Ikan lele merupakan bahan makanan yang cukup p...   Valid

# %%
raw.drop(['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
       'Unnamed: 6'],axis=1,inplace=True)

# %%
random = np.random.randint(0,len(barun))
print(random)
print(barun['0'][random])
# Out:
# 926
#
#
#
#
# Hasil periksa fakta ‘Ainayya Al Fatikhah.
# Unggahan video dengan klaim bahwa pasukan Indonesia berhasil menghabisi 73 pasukan Australia beserta sejumlah kiriman senjata dari Malaysia merupakan konten yang dimanipulasi. Faktanya, narator hanya membaca ulang artikel milik viva.co.id dengan judul “Rudal Rusia Bantai 73 Tentara Ukraina, Senjata Amerika Jadi Rongsokan”.
# =======
# [KATEGORI]: Konten yang dimanipulasi
#
# =======
# [SUMBER]:https://archive.cob.web.id/archive/1675981623.85364/singlefile.html (YouTube)
# =======
# [NARASI]: “TNI LUNCURKAN LUSINAN RUDAL BANTAI TENTARA AUSTRALIA, HINGGA SENJATA BANTUAN MALAYSIA JADI RONGSOKAN”
#
# =======
# [PENJELASAN]:
# Channel YouTube Dunia Berita (https://www.youtube.com/@duniaberita2029) pada 7 Februari 2023 mengunggah video dengan klaim bahwa Indonesia berhasil membantai 73 pasukan Australia menggunakan serangan meriam dan artileri yang difokuskan ke wilayah vital di Australia. Selain membantai 73 pasukan Australia, serangan Indonesia itu juga menghancurkan sejumlah kiriman senjata dari Malaysia. Melalui narasi video diketahui bahwa kota-kota di Australia, termasuk Ibukota Canberra, telah dihujani oleh serangan Indonesia. Adanya serangan dari Indonesia terhadap Australia ini disebabkan karena Indonesia murka lantaran Australia tidak menyerah terkait dengan isu Pulau Pasir.
# Setelah dilakukan penelusuran, faktanya narasi yang dibacakan dalam unggahan tersebut merupakan hasil suntingan karena narator hanya membaca ulang artikel milik viva.co.id (https://www.viva.co.id/) dengan mengubah subjek yang diberitakan. Artikel asli dengan judul “Rudal Rusia Bantai 73 Tentara Ukraina, Senjata Amerika Jadi Rongsokan” telah diunggah pada Jum’at, 15 Juli 2022. Dalam artikel tersebut, tertulis jika rudal milik Rusia-lah yang membantai tentara Ukraina, bukan rudal Indonesia yang membantai tentara Australia.
# Unggahan asli milik viva.co.id
# Dengan demikian, informasi yang disebarluaskan oleh Dunia Berita merupakan konten yang dimanipulasi.
# ====
# [REFERENSI]:https://www.viva.co.id/militer/militer-dunia/1497733-rudal-rusia-bantai-73-tentara-ukraina-senjata-amerika-jadi-rongsokan

# %%
random = np.random.randint(0,len(raw))
print(raw['Label'][random])
print(raw['Body'][random])
# Out:
# 0
# SUMBER: Media Sosial NARASI: TERIMA KASIH UNTUK SAUDARA TUA KAMI BANSER NU YANG TELAH MENYATAKAN SIAP MENURUNKAN 50.000 BANSER UNTUK MENJAGA UMAT ISLAM DALAM AKSI 212 DI JAKARTA SEMOGA BANSER TETAP JAYA ALLAHU AKBAR  !!! PENJELASAN: Informasi yang tersebar melalui media sosial itu telah dibantah langsung oleh Ketua Umum PP GP Ansor, Yaqut Cholil Qoumas atau akrab disapa Gus Yaqut melalui akun twitter pribadinya @GusYaqut. Ia menyatakan Pasti plintiran!!! Banser tdk akan turun!!! tulisnya. REFERENSI: 1. https://twitter.com/GusYaqut/status/801619351384178688 2. https://www.facebook.com/groups/fafhh/permalink/378443329154875/

# %%
random = np.random.randint(0,len(raw1))
print(raw1['kategori'][random])
print(raw1['berita'][random])
# Out:
# hoax
# "PGI siap berkati jasad muslim pendukung ahok yang tidak diurus oleh muslim"

# %%
random = np.random.randint(0,len(raw2))
print(raw2['tagging'][random])
print(raw2['berita'][random])
# Out:
# Valid
# Menteri Keuangan (Menkeu) Sri Mulyani menegaskan, pemerintah tak menyusun rencana kenaikan gaji presiden Bahkan, menurut dia, pemerintah sama sekali tak membahas mengenai rencana kenaikan gaji presiden  "Itu tidak ada dan belum pernah dibahas Dan menurut saya yang disampaikan Menpan bahwa itu adalah hoaks, ya memang begitu Jadi, kita tidak ada pembahasan mengenai hal itu sama sekali, sama sekali tidak ada," kata Sri Mulyani di Kompleks Istana Kepresidenan, Bogor, Jawa Barat, Senin (12/3) Sri Mulyani menyebut, pada era teknologi saat ini, banyak sekali oknum yang menyebarkan informasi-informasi yang belum tentu kebenarannya "Di dalam kurun medsos yang sekarang ini banyak sekali informasi-informasi yang dibuat, dan dokumen-dokumen yang dibuat seperti mirip dengan pemerintah, kemudian dipublikasikan," kata dia menjelaskan Sementara itu, terkait gaji PNS, Menkeu menyebut pemerintah akan menyusunnya sesuai dengan laporan nota keutangan yang disampaikan kepada DPR "Kalau gaji PNS nanti di dalam RKP 2019 dan RAPBN 2019 kita akan mendesain berdasarkan sesuai yang selama ini kita sampaikan pada dewan," ujarnya Seperti diketahui, muncul rancangan peraturan pemerintah (RPP) tentang gaji, tunjangan, dan fasilitas PNS Dalam RPP itu disebutkan penghitungan gaji presiden sebesar Rp 553422694/bulan dan wakil presiden sebesar Rp 368948462 per bulan Gaji presiden saat ini diketahui masih sangat jauh dari angka Rp 500 juta Gaji pokok presiden saat ini hanya sekitar Rp 30240000 tiap bulannya Hal ini sesuai dengan Pasal 2 UU Nomor 7 Tahun 1978, yang menyebutkan gaji presiden adalah enam kali gaji pokok tertinggi pejabat di Indonesia (ketua DPR, MA, dan BPK) Sementara itu, dalam PP No 75/2000 disebutkan, tiga pejabat tersebut menerima gaji Rp 5040000 tiap bulan Sedangkan, dalam Keppres No 68/2001 juga menyebutkan angka tunjangan jabatan presiden, yakni mencapai Rp 32500000 Sehingga, presiden menerima gaji sebesar Rp 62740000 tiap bulannya

# %%
raw1['kategori'] = [1 if x == 'valid' else 0 for x in raw1['kategori']]
raw2['tagging'] = [1 if x == 'Valid' else 0 for x in raw2['tagging']]

# %%
detik = pd.Series(detik['0'])
semen = pd.Series([1 for x in range(len(detik))])

# %%
text = pd.concat([raw['Body'],raw1['berita'],raw2['berita']]).reset_index().drop('index',axis=1)
target = pd.concat([raw['Label'],raw1['kategori'],raw2['tagging']]).reset_index().drop('index',axis=1)
raw_final = pd.DataFrame({'text':text[0],'target':target[0]})
raw_final
# Out:
#                                                    text  target
# 0     Foto: Kumparan.com Debunk ini berisi iKlarifik...       1
# 1     Foto Ilustrasi Perkosaan Debunk ini berisi kla...       1
# 2     Debunk ini berisi klarifikasi dari PT Ultrajay...       1
# 3     foto: tribunnews.com Debunk ini berisi Klrifik...       1
# 4     Foto: tribunnews.com (Jokowi sedang memantau l...       1
# ...                                                 ...     ...
# 2211  Kabar yang beredar seputar rencana kenaikan ga...       1
# 2212  Kabar yang beredar seputar rencana kenaikan ga...       1
# 2213  Akhir-akhir ini, beredar pemberitaan yang meny...       1
# 2214  Rancangan peraturan pemerintah (RPP) tentang G...       1
# 2215  Kabar yang beredar seputar rencana kenaikan ga...       1
#
# [2216 rows x 2 columns]

# %%
rawt = pd.concat([raw_final['text'],pd.Series(benan['0']),pd.Series(barun['0']),detik])
rawt = rawt.reset_index().drop('index',axis=1)[0]
rawl = [1 for x in range(len(benan))] + [0 for x in range(len(barun))]
rawl = pd.concat([raw_final['target'], pd.Series(rawl),semen])
rawl = rawl.reset_index().drop('index',axis=1)[0]
raw_final = pd.concat([rawt,rawl],axis=1,names=['text','target'])

# %%
raw_final.columns = ['text','target']
raw_final
# Out:
#                                                    text  target
# 0     Foto: Kumparan.com Debunk ini berisi iKlarifik...       1
# 1     Foto Ilustrasi Perkosaan Debunk ini berisi kla...       1
# 2     Debunk ini berisi klarifikasi dari PT Ultrajay...       1
# 3     foto: tribunnews.com Debunk ini berisi Klrifik...       1
# 4     Foto: tribunnews.com (Jokowi sedang memantau l...       1
# ...                                                 ...     ...
# 7664  \nJakarta - Polri mewajibkan pembuat SIM harus...       1
# 7665  \nJakarta - Wakil Ketua MPR RI Lestari Moerdij...       1
# 7666  \nJakarta - Sebanyak 19 pelaku Usaha Mikro Kec...       1
# 7667  \nJakarta - Dewan Pengawas (Dewas) KPK menemuk...       1
# 7668  \nJakarta - Seorang pria bernama Rifkho Achmad...       1
#
# [7669 rows x 2 columns]

# %%
raw_final['target'].value_counts()
# Out:
# 0    4141
# 1    3528
# Name: target, dtype: int64

# %%
random = np.random.randint(0,len(raw_final))
print(raw_final['target'][random])
print(raw_final['text'][random])
# Out:
# 1
#
# Jakarta - Kapolri Jenderal Listyo Sigit Prabowo meminta Korlantas Polri mengevaluasi ujian praktik dalam pembuatan surat izin mengemudi (SIM). Manuver zig-zag hingga angka 8 dalam praktik ujian SIM diminta diperbaiki.Seperti diketahui, manuver zig-zag dan membentuk angka 8 ini diterapkan dalam praktik uji SIM. Satpas SIM Polda Metro Jaya, salah satunya, yang menerapkan hal ini.Menanggapi soal arahan Kapolri tersebut, Dirlantas Polda Metro Jaya Kombes Latif Usman mengatakan pihaknya saat ini masih menunggu arahan lebih lanjut dari Korlantas Polri.
#
#
#     ADVERTISEMENT
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         SCROLL TO RESUME CONTENT
#
#
# "Kami akan menunggu instruksi dari Korlantas. Perubahan-perubahan yang seperti apa kita ikuti," ujar Latif kepada detikcom, Kamis (22/6/2023).Latif tidak berkomentar banyak soal evaluasi ujian praktik SIM ini. Namun, ia menegaskan teknis pelaksanaan evaluasi uji SIM masih menunggu arahan Korlantas lebih lanjut."Pasti ada petunjuk dan peraturannya dari Korlantas. Makanya kami masih menunggu arahan lebih lanjut dari Korlantas," imbuhnya.Baca juga: Anggota Komisi III DPR Dukung Penuh Evaluasi Pembuatan SIM: Bravo KapolriKapolri Minta EvaluasiSebelumnya, Kapolri dalam meminta Korlantas memperbaiki praktik uji SIM. Manuver zig-zag hingga angka 8 diminta dievaluasi kembali."Pembuatan SIM, ini masih dilihat sulit. Laporan kasus juga sama, balik nama kendaraan juga sama, dan seterusnya. Saat ini kita terus melakukan upaya perbaikan," kata Sigit."Saya kira Pak Kadiv TIK, Pak As Ops, Pak Kabik, Kakorlantas, sedang berusaha melakukan perbaikan, dari yang awalnya manual kita ubah menjadi digitalisasi, sehingga masyarakat bisa mendapatkan pelayanan cukup dengan menggunakan aplikasi yang saat ini kita siapkan, kita sedang satukan semua aplikasi menjadi satu layanan namanya Super Apps," sambungnya.Jenderal Sigit kemudian menyinggung soal materi ujian pembuatan SIM C, antara lain manuver zig-zag dan angka delapan. Sigit meminta Kakorlantas melakukan perbaikan terkait materi ujian tersebut."Dan khusus untuk pembuatan SIM, ini saya minta Kakorlantas tolong dilakukan perbaikan, yang namanya angka delapan itu masih sesuai atau tidak, yang namanya melewati apa itu, zig-zag zig-zag itu, masih sesuai atau tidak. Saya kira kalau memang sudah tidak relevan, perbaiki," ujarnya.Sigit meminta agar segera dilakukan evaluasi dalam penerbitan SIM dengan tujuan untuk mempermudah masyarakat, dengan tanpa mengurangi aspek keselamatan berkendara. Bagi Sigit, yang penting adalah bagaimana masyarakat punya keterampilan saat berkendara, dan menghargai keselamatan pribadi dan pengguna jalan."Jangan terkesan bahwa pembuatan ujiannya khususnya praktek ini hanya untuk mempersulit dan ujung-ujungnya di bawah meja. Nggak tes malah lulus. Ini harus dihilangkan," tegas Sigit.Baca juga: Sentilan Kapolri, Cuma Sepersepuluh Wisudawan STIK Bakal Lolos Uji SIMSimak juga 'Saat Korlantas Bakal Sebar Buku Ujian SIM ke Sekolah-Perpustakaan':[Gambas:Video 20detik]
# (wnv/mea)
#
#
# ujian praktik sim uji praktik sim c sim c polda metro jaya jabodetabek korlantas polri

# %%
corpus = pd.read_csv('id.stopwords.02.01.2016.txt',sep=r'\n')
corpus
# Out:
#          ada
# 0     adalah
# 1     adanya
# 2     adapun
# 3       agak
# 4    agaknya
# ..       ...
# 752     wong
# 753    yaitu
# 754    yakin
# 755    yakni
# 756     yang
#
# [757 rows x 1 columns]

# %%
fact = StemmerFactory()
stemmer = fact.create_stemmer()

# %%
from nltk.tokenize import word_tokenize
def text_preprocessing(text):
    pattern = r'http[s]?:\/\/([a-z-.]+)\/[^ \n]*'
    pattern1 = r'http[^ \n]+'
    pattern2 = r'[0-9]+'
    pattern3 = r'@[^ \n]+|#[^ \n]+'
    rem = re.findall(pattern,text)
    data = re.sub(pattern3,'',text)
    data = data.lower()
    for x in range(len(rem)):
        data = re.sub(pattern1,rem[x],data,count=1)
    data = stemmer.stem(data)
    data = re.sub(pattern2,'@',data)
    data = ' '.join([x for x in data.split() if x not in nltk.corpus.stopwords.words('indonesian')])
    return data

# %%
text = raw_final['text']
target = raw_final['target']

# %%
text = text.apply(text_preprocessing)

# %%
text
# Out:
# 0       foto kumpar com debunk isi iklarifikasi pertam...
# 1       foto ilustrasi perkosa debunk isi klarifikasi ...
# 2       debunk isi klarifikasi pt ultrajaya milk indus...
# 3       foto tribunnews com debunk isi klrifikasi sety...
# 4       foto tribunnews com jokowi pantau lokasi benca...
#                               ...
# 7664    jakarta - polri wajib sim milik sertifikat ver...
# 7665    jakarta - wakil ketua mpr ri lestari moerdijat...
# 7666    jakarta - @ laku usaha mikro umkm lokal bina p...
# 7667    jakarta - dewan awas dewas kpk temu duga pungu...
# 7668    jakarta - orang pria nama rifkho achmad bawazi...
# Name: text, Length: 7669, dtype: object

# %%
contoh_data_mentah = raw_final['text'][6548]
contoh_data_mentah
# Out:
# '\nJakarta - Ketua KPK Firli Bahuri terlihat hadir di pemakaman Wakil Ketua Komisi III DPR RI Fraksi Partai Gerindra Desmond Junaedi yang dilakukan di Al-Azhar Memorial Garden, Karawang, Jawa Barat. Firli mengaku berduka atas kabar kepergian Desmond.Filri terlihat hadir mengenakan baju berwarna putih dengan peci. Selepas mengikuti prosesi pemakaman Desmond, Filri kemudian melakukan tabur bunga di makam Desmond sembari menyampaikan doa."Kita sama-sama berduka atas wafatnya saudara-sahabat kita Bapak Desmond Junaedi Mahesa. Saya kira beliau meninggalkan banyak perjuangan dan bagi kita yang sekarang harus melanjutkan perjuangan beliau dan cita-cita beliau untuk mewujudkan cita-cita bangsa kita," ujar Firli kepada wartawan, Sabtu (24/6/2023).\n\n\r\n    ADVERTISEMENT\r\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n        SCROLL TO RESUME CONTENT\r\n  \n\nBaca juga: Mahfud Kenang Desmond Mahesa Sosok yang Berani Kritik Siapa SajaSelain Filri, sejumlah elite Partai Gerindra, seperti Sekjen Partai Gerindra Ahmad Muzani dan Waketum Partai Gerindra Habiburokhman, turut hadir di pemakaman. Firli mengaku perjuangan Desmond berkontribusi pada kondisi yang dirasakan di Indonesia saat ini."Melalui perjuangan beliaulah kita bisa seperti sekarang dan tentu kita berterima kasih kepada almarhum dan keluarganya," lanjutnya.Kabar kepergian Desmond disampaikan oleh Ketua Harian DPP Partai Gerindra Sufmi Dasco Ahmad, yang saat ini masih berada di Makkah untuk menunaikan ibadah haji. Dasco mendapat kabar dari istri Desmond.Baca juga: Mega di Depan Airlangga hingga Zulhas: Ada yang Masih Mikir Ikut PDIP"Memang Desmond dari kemarin masuk Rumah Sakit Mayapada. Dan, hari ini pukul empat Subuh telah meninggal dunia. Saya kebetulan di Makkah, mendapat telepon dari istrinya yang mengabarkan berita duka cita ini," kata Dasco.Desmond adalah aktivis 1998 yang kemudian menjadi politikus partai Gerindra. Dilihat dari situs resmi DPR, Desmond lahir di Banjarmasin pada 12 Desember 1965.Saat ini, Desmond menjabat Wakil Ketua Komisi III DPR RI. Dia terpilih menjadi anggota DPR RI periode 2019/2024 wakil dari Daerah Pemilihan (Dapil) Banten II.Baca juga: Prabowo Kenang Perjuangan Desmond Besarkan Partai GerindraSimak Video: Prabowo Kenang Perjuangan Desmond Besarkan Partai Gerindra[Gambas:Video 20detik]\n(ygs/ygs)\n\n\ndesmond mahesa meninggal dunia firli bahuri gerindra desmond mahesa \n\n'

# %%
contoh_data_praproses = text_preprocessing(contoh_data_mentah)
contoh_data_praproses
# Out:
# 'jakarta - ketua kpk firli bahuri lihat hadir makam wakil ketua komisi iii dpr ri fraksi partai gerindra desmond junaedi laku al-azhar memorial garden karawang jawa barat firli duka kabar pergi desmond filri lihat hadir kena baju warna putih peci lepas prosesi makam desmond filri laku tabur bunga makam desmond sembari doa duka wafat saudara-sahabat desmond junaedi mahesa beliau tinggal juang juang beliau cita beliau wujud cita bangsa firli wartawan sabtu @ @ @ advertisement scroll to resume content baca mahfud kenang desmond mahesa sosok berani kritik sajaselain filri elite partai gerindra sekjen partai gerindra ahmad muzani waketum partai gerindra habiburokhman hadir makam firli juang desmond kontribusi kondisi indonesia juang biau terima kasih almarhum keluarga kabar pergi desmond ketua dpp partai gerindra sufmi dasco ahmad makkah tunai ibadah haji dasco kabar istri desmond baca mega airlangga zulhas mikir pdip desmond kemarin masuk rumah sakit mayapada subuh tinggal dunia makkah telepon istri abar berita duka cita dasco desmond aktivis @ politikus partai gerindra lihat situs resmi dpr desmond lahir banjarmasin @ desember @ desmond jabat wakil ketua komisi iii dpr ri pilih anggota dpr ri periode @ @ wakil daerah pilih dapil banten ii baca prabowo kenang juang desmond partai gerindrasimak video prabowo kenang juang desmond partai gerindra gambas video @detik ygs ygs desmond mahesa tinggal dunia firli bahuri gerindra desmond mahesa'

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
baseline_model = Pipeline([
    ('tfidf',TfidfVectorizer()),
    ('bayes',MultinomialNB())
])

# %%
from sklearn.model_selection import train_test_split
seed = np.random.randint(10,200)
print(seed)
train_text, test_text, train_label, test_label = train_test_split(text, target, test_size=0.2, random_state=seed)
baseline_model.fit(train_text,train_label)
# Out:
# 28
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('bayes', MultinomialNB())])

# %%
train_label
# Out:
# 5333    0
# 2942    0
# 3213    0
# 6014    1
# 214     1
#        ..
# 6132    1
# 5398    0
# 1541    0
# 4089    0
# 1281    1
# Name: target, Length: 6135, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_recall_fscore_support,classification_report
import tensorflow as tf
def score_model(y_true,y_pred):
    acc = accuracy_score(y_true,y_pred)*100
    prec,rec,fsc,_ = precision_recall_fscore_support(y_true,y_pred,average='weighted')
    model_results = {"accuracy": acc,
                  "precision": prec,
                  "recall": rec,
                  "f1": fsc}
    sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d',annot_kws={'size':20})
    return model_results

# %%
baseline_pred = baseline_model.predict(test_text)
score_model(test_label,baseline_pred)
# Out:
# {'accuracy': 90.41720990873533,
#  'precision': 0.9055323253615686,
#  'recall': 0.9041720990873533,
#  'f1': 0.9039973111211703}

# %%
from tensorflow.keras.layers import TextVectorization,Embedding
avg = round(sum([len(x.split()) for x in text])/len(text))
max_vocab = 50000

# %%
# from tensorflow.keras.preprocessing.text import Tokenizer
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(train_text)

# X_train = tokenizer.texts_to_sequences(train_text)
# X_test = tokenizer.texts_to_sequences(test_text)

# max_length = avg
# X_train = pad_sequences(X_train, maxlen=max_length, padding='post')
# X_test = pad_sequences(X_test, maxlen=max_length, padding='post')

# %%
import gensim
import gensim.downloader as api
w4v = api.load('word2vec-google-news-300',return_path=True)
# Out:
# [===-----------------------------------------------] 6.4% 106.5/1662.8MB downloaded

# %%
prep = gensim.models.Phrases([x.split() for x in train_text])
w3v = gensim.models.KeyedVectors.load('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[547], line 2
#       1 from gensim.test.utils import datapath
# ----> 2 w3v = gensim.models.KeyedVectors.load_word2vec_format(datapath('C:\\Users\\LENOVO\\Desktop\\Project\\embedding\\glove.6B.100d.txt'),binary=True)
#
# File ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:1719, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1672 @classmethod
#    1673 def load_word2vec_format(
#    1674         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1675         limit=None, datatype=REAL, no_header=False,
#    1676     ):
#    1677     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1678
#    1679     Warnings
#    (...)
#    1717
#    1718     """
# -> 1719     return _load_word2vec_format(
#    1720         cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1721         limit=limit, datatype=datatype, no_header=no_header,
#    1722     )
#
# File ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:2059, in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header, binary_chunk_size)
#    2057 else:
#    2058     header = utils.to_unicode(fin.readline(), encoding=encoding)
# -> 2059     vocab_size, vector_size = [int(x) for x in header.split()]  # throws for invalid file format
#    2060 if limit:
#    2061     vocab_size = min(vocab_size, limit)
#
# File ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:2059, in <listcomp>(.0)
#    2057 else:
#    2058     header = utils.to_unicode(fin.readline(), encoding=encoding)
# -> 2059     vocab_size, vector_size = [int(x) for x in header.split()]  # throws for invalid file format
#    2060 if limit:
#    2061     vocab_size = min(vocab_size, limit)
#
# ValueError: invalid literal for int() with base 10: 'the'

# %%
w2v.wv[text[3543].split()]
# Out:
# array([[ 0.3554658 ,  0.04137984, -0.4057788 , ..., -0.42473042,
#          0.6001936 , -0.63904655],
#        [ 2.846383  ,  0.22098738,  0.7186526 , ...,  0.6701247 ,
#         -1.9227387 , -2.2720046 ],
#        [ 1.8516768 , -0.32199875,  0.7260242 , ..., -1.1238655 ,
#         -0.7322807 , -0.09687594],
#        ...,
#        [ 0.09858517,  0.07106326, -0.06520353, ..., -0.02655877,
#          0.24456224,  0.06940044],
#        [ 1.2340635 ,  0.77633655, -0.19094108, ...,  0.5134379 ,
#          1.1699055 ,  1.6122164 ],
#        [-1.8823626 , -0.71564806, -0.6682016 , ..., -0.7653656 ,
#          1.0703028 , -0.20224524]], dtype=float32)

# %%
def vectorize(sentence):
    vectorized=[]
    words = sentence.split()
    for word in words:
        if word in w2v.wv:
            vectorized.append(w2v.wv[word])
        else:
            vectorized.append(np.zeros(128))
    return np.array(vectorized)

# %%
def padding(text):
    padded=[]
    for i,v in enumerate(text):
        vector=[]
        if len(v) < 205:
            pdc = 205 - len(v)
            pad = np.zeros((pdc,128))
            vector = np.append(v,pad,axis=0)
        else:
            vector = v[:205]
        padded.append(vector)
    return np.array(padded)

# %%
train_text.shape
# Out:
# (6135,)

# %%
train_text = train_text.apply(vectorize)
test_text = test_text.apply(vectorize)

# %%
train_text.shape
# Out:
# (6135,)

# %%
train_text = padding(train_text)
test_text = padding(test_text)

# %%
train_text.shape,test_text.shape
# Out:
# ((6135, 205, 128), (1534, 205, 128))

# %%
import tensorflow as tf
train_text = tf.convert_to_tensor(train_text)
test_text = tf.convert_to_tensor(test_text)

# %%
train_text
# Out:
# <tf.Tensor: shape=(6135, 205, 128), dtype=float64, numpy=
# array([[[ 3.55465800e-01,  4.13798355e-02, -4.05778795e-01, ...,
#          -4.24730420e-01,  6.00193620e-01, -6.39046550e-01],
#         [ 2.84638309e+00,  2.20987380e-01,  7.18652606e-01, ...,
#           6.70124710e-01, -1.92273867e+00, -2.27200460e+00],
#         [ 1.85167682e+00, -3.21998745e-01,  7.26024210e-01, ...,
#          -1.12386549e+00, -7.32280672e-01, -9.68759432e-02],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[-1.28750265e+00,  7.55235970e-01,  8.13066661e-01, ...,
#          -1.46855295e+00, -9.23016146e-02,  8.20501983e-01],
#         [-1.05544770e+00,  1.66656077e-01,  1.36675686e-01, ...,
#           1.07208714e-01, -1.57243192e+00, -1.65802264e+00],
#         [-1.16454625e+00,  9.03390646e-01, -5.55334270e-01, ...,
#           2.34686542e+00, -2.13834718e-01,  8.50666940e-01],
#         ...,
#         [ 1.55664548e-01, -3.58670428e-02, -1.16714634e-01, ...,
#          -1.19859679e-02,  2.64245242e-01,  1.61277473e-01],
#         [ 1.08094430e-02, -2.14600414e-02, -1.21937133e-02, ...,
#           3.28574739e-02, -5.33234037e-04,  2.00408474e-02],
#         [-6.88680708e-01, -1.05136478e+00, -3.48055691e-01, ...,
#           4.53753099e-02, -1.26974761e+00, -2.56423295e-01]],
#
#        [[-1.28750265e+00,  7.55235970e-01,  8.13066661e-01, ...,
#          -1.46855295e+00, -9.23016146e-02,  8.20501983e-01],
#         [-1.05544770e+00,  1.66656077e-01,  1.36675686e-01, ...,
#           1.07208714e-01, -1.57243192e+00, -1.65802264e+00],
#         [ 3.55465800e-01,  4.13798355e-02, -4.05778795e-01, ...,
#          -4.24730420e-01,  6.00193620e-01, -6.39046550e-01],
#         ...,
#         [-1.82998896e-01, -1.12180352e+00, -1.47788182e-01, ...,
#           1.43828130e+00, -2.85183597e+00, -9.00459409e-01],
#         [-4.67548549e-01, -4.10021693e-01, -5.77962875e-01, ...,
#          -1.01138508e+00, -6.55592918e-01,  3.98275137e-01],
#         [-6.49444103e-01,  2.03386471e-01, -3.89042377e-01, ...,
#           5.70331097e-01,  1.61004841e-01, -4.74973209e-02]],
#
#        ...,
#
#        [[-1.17502439e+00, -3.23980898e-01, -3.63137573e-01, ...,
#          -4.55669165e-01, -1.68996811e+00,  3.68957072e-01],
#         [ 6.45420015e-01,  1.33765042e+00, -7.72019267e-01, ...,
#           2.09325123e+00, -2.72153831e+00,  1.84741473e+00],
#         [ 1.52750030e-01, -4.58704859e-01, -3.55732411e-01, ...,
#          -2.30561927e-01,  3.72274965e-01,  2.81749934e-01],
#         ...,
#         [-1.37887776e-01,  7.01534227e-02,  3.36351067e-01, ...,
#          -2.59743214e-01, -6.86965287e-01, -3.52862865e-01],
#         [-4.10623074e-01, -6.93140268e-01, -5.13413846e-02, ...,
#           2.40814880e-01, -8.94120157e-01,  3.05989027e-01],
#         [-1.89094067e-01, -9.68195915e-01, -2.17442572e-01, ...,
#           3.19605261e-01, -7.83820450e-01, -1.23474050e+00]],
#
#        [[ 3.55465800e-01,  4.13798355e-02, -4.05778795e-01, ...,
#          -4.24730420e-01,  6.00193620e-01, -6.39046550e-01],
#         [ 2.84638309e+00,  2.20987380e-01,  7.18652606e-01, ...,
#           6.70124710e-01, -1.92273867e+00, -2.27200460e+00],
#         [ 1.85167682e+00, -3.21998745e-01,  7.26024210e-01, ...,
#          -1.12386549e+00, -7.32280672e-01, -9.68759432e-02],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 2.94686370e-02,  9.73978043e-01,  4.82696950e-01, ...,
#          -1.50554627e-01, -1.93418264e-01,  1.23229891e-01],
#         [ 9.61102664e-01,  6.65325403e-01,  1.01656720e-01, ...,
#           1.14504528e+00, -6.48430526e-01,  8.12725306e-01],
#         [ 8.48419815e-02, -6.68173954e-02,  2.77899615e-02, ...,
#           8.54995996e-02, -1.61689073e-02,  6.62060976e-02],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]])>

# %%
tvx = TextVectorization(
    max_tokens=max_vocab,
    output_sequence_length=avg,
    output_mode='int'
)

# %%
# tvx.adapt(train_text)

# %%
# random = np.random.randint(0,len(text))
# print(random)
# print(text[random])
# print(tvx(text[random]))

# %%
vocab = tvx.get_vocabulary()
vocab[:30],vocab[-30:]
# Out:
# (['', '[UNK]'], ['', '[UNK]'])

# %%
ebd = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding'
)

# %%
from tensorflow.keras import layers,Model,Sequential
inputs = layers.Input(shape=(205,128))
lay = layers.GlobalMaxPooling1D()(inputs)
lay = layers.Dense(64,activation='relu')(lay)
lay = layers.Dense(16,activation='relu')(lay)
outputs = layers.Dense(1,activation='sigmoid')(lay)
model_1 = Model(inputs,outputs,name='model_1_dense')

# %%
model_1.compile(loss='binary_crossentropy', optimizer = 'adam',metrics=['accuracy'])

# %%
model_1.summary()
# Out:
# Model: "model_1_dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_52 (InputLayer)       [(None, 205, 128)]        0
#
#  global_max_pooling1d_27 (Gl  (None, 128)              0
#  obalMaxPooling1D)
#
#  dense_82 (Dense)            (None, 64)                8256
#
#  dense_83 (Dense)            (None, 16)                1040
#
#  dense_84 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 9,313
# Trainable params: 9,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from helper_functions import create_tensorboard_callback
early_stop = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1,patience=3)
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
model_1.fit(
    train_text,
    train_label,
    epochs=40,
    validation_data=(test_text,test_label),
    callbacks=[max_mod,
              early_stop,]
)
# Out:
# Epoch 1/40
# 190/192 [============================>.] - ETA: 0s - loss: 0.3669 - accuracy: 0.8214INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 4s 15ms/step - loss: 0.3668 - accuracy: 0.8215 - val_loss: 0.2388 - val_accuracy: 0.9003
# Epoch 2/40
# 183/192 [===========================>..] - ETA: 0s - loss: 0.2546 - accuracy: 0.8861INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 2s 11ms/step - loss: 0.2535 - accuracy: 0.8869 - val_loss: 0.2068 - val_accuracy: 0.9205
# Epoch 3/40
# 184/192 [===========================>..] - ETA: 0s - loss: 0.2186 - accuracy: 0.9027INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 2s 12ms/step - loss: 0.2174 - accuracy: 0.9035 - val_loss: 0.1818 - val_accuracy: 0.9250
# Epoch 4/40
# 187/192 [============================>.] - ETA: 0s - loss: 0.2067 - accuracy: 0.9134INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 2s 10ms/step - loss: 0.2066 - accuracy: 0.9136 - val_loss: 0.1642 - val_accuracy: 0.9348
# Epoch 5/40
# 192/192 [==============================] - 1s 6ms/step - loss: 0.1910 - accuracy: 0.9183 - val_loss: 0.1644 - val_accuracy: 0.9309
# Epoch 6/40
# 192/192 [==============================] - 1s 6ms/step - loss: 0.1760 - accuracy: 0.9250 - val_loss: 0.1954 - val_accuracy: 0.9224
# Epoch 7/40
# 183/192 [===========================>..] - ETA: 0s - loss: 0.1781 - accuracy: 0.9252INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 2s 9ms/step - loss: 0.1791 - accuracy: 0.9245 - val_loss: 0.1505 - val_accuracy: 0.9394
# Epoch 8/40
# 189/192 [============================>.] - ETA: 0s - loss: 0.1742 - accuracy: 0.9264INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 2s 9ms/step - loss: 0.1734 - accuracy: 0.9268 - val_loss: 0.1445 - val_accuracy: 0.9400
# Epoch 9/40
# 192/192 [==============================] - 1s 5ms/step - loss: 0.1685 - accuracy: 0.9297 - val_loss: 0.1529 - val_accuracy: 0.9394
# Epoch 10/40
# 188/192 [============================>.] - ETA: 0s - loss: 0.1657 - accuracy: 0.9304INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 2s 8ms/step - loss: 0.1651 - accuracy: 0.9309 - val_loss: 0.1362 - val_accuracy: 0.9472
# Epoch 11/40
# 192/192 [==============================] - 1s 5ms/step - loss: 0.1494 - accuracy: 0.9372 - val_loss: 0.1580 - val_accuracy: 0.9342
# Epoch 12/40
# 192/192 [==============================] - 1s 5ms/step - loss: 0.1571 - accuracy: 0.9350 - val_loss: 0.1425 - val_accuracy: 0.9439
# Epoch 13/40
# 192/192 [==============================] - 1s 5ms/step - loss: 0.1525 - accuracy: 0.9376 - val_loss: 0.1407 - val_accuracy: 0.9407
# Epoch 13: early stopping

# %%
loss = pd.DataFrame(model_1.history.history)
loss.plot()
# Out:
# <Axes: >

# %%
model_1.load_weights('weight_best.tf/')

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_1)

# %%
model_1.evaluate(test_text,test_label)
# Out:
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1362 - accuracy: 0.9472
# [0.1361856311559677, 0.9471968412399292]

# %%
ebd.weights
# Out:
# []

# %%
pred_dense = np.squeeze(np.round(model_1.predict(test_text)))
score_model(test_label,pred_dense)
# Out:
# 48/48 [==============================] - 0s 5ms/step
# {'accuracy': 94.71968709256845,
#  'precision': 0.9472975689678627,
#  'recall': 0.9471968709256845,
#  'f1': 0.947179048393307}

# %%
# result = pd.DataFrame(columns=['accuracy','precision','recall','f1-score'])
# for x in range(4):
#     random = np.random.randint(10,200)
#     print('Seeds : ',random)
#     train_text, test_text, train_label, test_label = train_test_split(text, target, test_size=0.2, random_state=random)
#     tf.keras.backend.clear_session()
#     early_stop = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1,patience=2)
#     model_1.fit(
#         train_text,
#         train_label,
#         epochs=40,
#         validation_data=(test_text,test_label),
#         callbacks=[early_stop])
#     pred_dense = np.squeeze(np.round(model_1.predict(test_text)))
#     acc = accuracy_score(test_label,pred_dense)*100
#     prec,rec,fsc,_ = precision_recall_fscore_support(test_label,pred_dense,average='weighted')
#     model_results = {"accuracy": acc,
#                   "precision": prec,
#                   "recall": rec,
#                   "f1-score": fsc}
#     result = pd.concat([result,pd.DataFrame(model_results,index=[x])])
# result = pd.concat([result,pd.DataFrame(result.mean()).transpose()])
# result

# %%
# pred_dense = np.squeeze(np.round(model_1.predict(test_text)))
# score_model(test_label,pred_dense)

# %%
# vocab = tvx.get_vocabulary()
# wgt = model_1.get_layer('embedding').get_weights()[0]

# %%
# Code below is adapted from: https://www.tensorflow.org/tutorials/text/word_embeddings#retrieve_the_trained_word_embeddings_and_save_them_to_disk
# import io

# # Create output writers
# out_v = io.open("embedding_vectors.tsv", "w", encoding="utf-8")
# out_m = io.open("embedding_metadata.tsv", "w", encoding="utf-8")

# # Write embedding vectors and words to file
# for num, word in enumerate( vocab):
#   if num == 0: 
#      continue # skip padding token
#   vec = wgt[num]
#   out_m.write(word + "\n") # write words to file
#   out_v.write("\t".join([str(x) for x in vec]) + "\n") # write corresponding word vector to file
# out_v.close()
# out_m.close()

# # Download files locally to upload to Embedding Projector
# try:
#   from google.colab import files
# except ImportError:
#   pass
# else:
#   files.download("embedding_vectors.tsv")
#   files.download("embedding_metadata.tsv")

# %%
ebd_2 = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding_2'
)

# %%
inputs = layers.Input(shape=(205,128))
lay = layers.LSTM(64,return_sequences=True)(inputs)
lay = layers.GlobalMaxPool1D()(lay)
lay = layers.Dropout(0.5)(lay)
lay = layers.Dense(16,activation='relu')(lay)
outputs = layers.Dense(1,activation='sigmoid')(lay)
model_2 = Model(inputs,outputs,name='model_2_lstm')

# %%
model_2.compile(loss='binary_crossentropy', optimizer = 'adam',metrics=['accuracy'])

# %%
model_2.summary()
# Out:
# Model: "model_2_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 205, 128)]        0
#
#  lstm (LSTM)                 (None, 205, 64)           49408
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 16)                1040
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 50,465
# Trainable params: 50,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1,patience=3)
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
model_2.fit(
    train_text,
    train_label,
    epochs=16,
    validation_data=(test_text,test_label),
    callbacks=[early_stop,max_mod])
# Out:
# Epoch 1/16
# 192/192 [==============================] - ETA: 0s - loss: 0.2557 - accuracy: 0.8830
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 18s 85ms/step - loss: 0.2557 - accuracy: 0.8830 - val_loss: 0.1432 - val_accuracy: 0.9348
# Epoch 2/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1357 - accuracy: 0.9384
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 15s 80ms/step - loss: 0.1357 - accuracy: 0.9384 - val_loss: 0.1218 - val_accuracy: 0.9407
# Epoch 3/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1151 - accuracy: 0.9526
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 15s 78ms/step - loss: 0.1151 - accuracy: 0.9526 - val_loss: 0.1046 - val_accuracy: 0.9492
# Epoch 4/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9522
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 15s 80ms/step - loss: 0.1049 - accuracy: 0.9522 - val_loss: 0.0981 - val_accuracy: 0.9537
# Epoch 5/16
# 192/192 [==============================] - 11s 60ms/step - loss: 0.0919 - accuracy: 0.9591 - val_loss: 0.0992 - val_accuracy: 0.9537
# Epoch 6/16
# 191/192 [============================>.] - ETA: 0s - loss: 0.0886 - accuracy: 0.9638
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 15s 79ms/step - loss: 0.0885 - accuracy: 0.9638 - val_loss: 0.0946 - val_accuracy: 0.9550
# Epoch 7/16
# 192/192 [==============================] - 12s 60ms/step - loss: 0.0835 - accuracy: 0.9658 - val_loss: 0.1002 - val_accuracy: 0.9452
# Epoch 8/16
# 192/192 [==============================] - 12s 60ms/step - loss: 0.0775 - accuracy: 0.9679 - val_loss: 0.0958 - val_accuracy: 0.9511
# Epoch 9/16
# 192/192 [==============================] - 12s 60ms/step - loss: 0.0705 - accuracy: 0.9685 - val_loss: 0.0939 - val_accuracy: 0.9511
# Epoch 9: early stopping

# %%
model_2.load_weights('weight_best.tf/')

# %%
model_2.evaluate(test_text,test_label)
# Out:
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0946 - accuracy: 0.9550
# [0.09459152072668076, 0.9550195336341858]

# %%
plot_model(model_2)

# %%
pred_lstm = np.squeeze(np.round(model_2.predict(test_text)))
score_model(test_label,pred_lstm)
# Out:
# 48/48 [==============================] - 2s 29ms/step
# {'accuracy': 95.50195567144719,
#  'precision': 0.9553014269562001,
#  'recall': 0.9550195567144719,
#  'f1': 0.9549425185327388}

# %%
ebd_3 = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding_3'
)

# %%
inputs = layers.Input(shape=(205,128))
lay = layers.Dense(128,activation='relu')(inputs)
lay = layers.Bidirectional(layers.LSTM(64,return_sequences=True))(lay)
lay = layers.GlobalMaxPool1D()(lay)
lay = layers.Dense(32,activation='relu')(lay)
outputs = layers.Dense(1,activation='sigmoid')(lay)
model_3 = Model(inputs,outputs,name='model_3_bi-lstm')

# %%
model_3.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_3.summary()
# Out:
# Model: "model_3_bi-lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_68 (InputLayer)       [(None, 205, 128)]        0
#
#  dense_112 (Dense)           (None, 205, 128)          16512
#
#  bidirectional_14 (Bidirecti  (None, 205, 128)         98816
#  onal)
#
#  global_max_pooling1d_35 (Gl  (None, 128)              0
#  obalMaxPooling1D)
#
#  dense_113 (Dense)           (None, 32)                4128
#
#  dense_114 (Dense)           (None, 1)                 33
#
# =================================================================
# Total params: 119,489
# Trainable params: 119,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
model_3.fit(
    train_text,
    train_label,
    epochs=16,
    validation_data=(test_text,test_label),
    callbacks=[max_mod,
              early_stop])
# Out:
# Epoch 1/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9242
# WARNING:absl:Found untraced functions such as lstm_cell_41_layer_call_fn, lstm_cell_41_layer_call_and_return_conditional_losses, lstm_cell_42_layer_call_fn, lstm_cell_42_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 86s 423ms/step - loss: 0.1701 - accuracy: 0.9242 - val_loss: 0.1274 - val_accuracy: 0.9446
# Epoch 2/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9576
# WARNING:absl:Found untraced functions such as lstm_cell_41_layer_call_fn, lstm_cell_41_layer_call_and_return_conditional_losses, lstm_cell_42_layer_call_fn, lstm_cell_42_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 102s 531ms/step - loss: 0.0968 - accuracy: 0.9576 - val_loss: 0.1126 - val_accuracy: 0.9478
# Epoch 3/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9672
# WARNING:absl:Found untraced functions such as lstm_cell_41_layer_call_fn, lstm_cell_41_layer_call_and_return_conditional_losses, lstm_cell_42_layer_call_fn, lstm_cell_42_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 77s 403ms/step - loss: 0.0765 - accuracy: 0.9672 - val_loss: 0.1047 - val_accuracy: 0.9550
# Epoch 4/16
# 192/192 [==============================] - 65s 336ms/step - loss: 0.0662 - accuracy: 0.9726 - val_loss: 0.1025 - val_accuracy: 0.9550
# Epoch 5/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0529 - accuracy: 0.9773
# WARNING:absl:Found untraced functions such as lstm_cell_41_layer_call_fn, lstm_cell_41_layer_call_and_return_conditional_losses, lstm_cell_42_layer_call_fn, lstm_cell_42_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 78s 405ms/step - loss: 0.0529 - accuracy: 0.9773 - val_loss: 0.0918 - val_accuracy: 0.9661
# Epoch 6/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9809
# WARNING:absl:Found untraced functions such as lstm_cell_41_layer_call_fn, lstm_cell_41_layer_call_and_return_conditional_losses, lstm_cell_42_layer_call_fn, lstm_cell_42_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 83s 431ms/step - loss: 0.0456 - accuracy: 0.9809 - val_loss: 0.0887 - val_accuracy: 0.9681
# Epoch 7/16
# 192/192 [==============================] - 74s 386ms/step - loss: 0.0341 - accuracy: 0.9865 - val_loss: 0.1192 - val_accuracy: 0.9570
# Epoch 8/16
# 192/192 [==============================] - 68s 356ms/step - loss: 0.0375 - accuracy: 0.9842 - val_loss: 0.1026 - val_accuracy: 0.9609
# Epoch 9/16
# 192/192 [==============================] - 69s 359ms/step - loss: 0.0268 - accuracy: 0.9904 - val_loss: 0.1117 - val_accuracy: 0.9628
# Epoch 9: early stopping

# %%
model_3.load_weights('weight_best.tf/')

# %%
model_3.evaluate(test_text,test_label)
# Out:
# 48/48 [==============================] - 6s 134ms/step - loss: 0.0887 - accuracy: 0.9681
# [0.08872288465499878, 0.96805739402771]

# %%
plot_model(model_3)

# %%
pred_bilstm = np.squeeze(np.round(model_3.predict(test_text)))
score_model(test_label,pred_bilstm)
# Out:
# 48/48 [==============================] - 9s 156ms/step
# {'accuracy': 96.80573663624511,
#  'precision': 0.9680571961546065,
#  'recall': 0.9680573663624511,
#  'f1': 0.9680535651390872}

# %%
ebd_4 = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding_4'
)

# %%
inputs = layers.Input(shape=(205,128))
lay = layers.GRU(64,return_sequences=True)(inputs)
lay = layers.GlobalMaxPool1D()(lay)
lay = layers.Dropout(0.5)(lay)
outputs = layers.Dense(1,activation='sigmoid')(lay)
model_4 = Model(inputs,outputs,name='model_4_gru')

# %%
model_4.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_4.summary()
# Out:
# Model: "model_4_gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 205, 128)]        0
#
#  gru (GRU)                   (None, 205, 64)           37248
#
#  global_max_pooling1d_3 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 37,313
# Trainable params: 37,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
model_4.fit(
    train_text,
    train_label,
    epochs=16,
    validation_data=(test_text,test_label),
    callbacks=[max_mod,
              early_stop])
# Out:
# Epoch 1/16
# 192/192 [==============================] - ETA: 0s - loss: 0.2574 - accuracy: 0.8812
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 19s 86ms/step - loss: 0.2574 - accuracy: 0.8812 - val_loss: 0.1442 - val_accuracy: 0.9296
# Epoch 2/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9434
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 16s 85ms/step - loss: 0.1219 - accuracy: 0.9434 - val_loss: 0.1223 - val_accuracy: 0.9400
# Epoch 3/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9552
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 16s 83ms/step - loss: 0.1037 - accuracy: 0.9552 - val_loss: 0.1162 - val_accuracy: 0.9439
# Epoch 4/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9601
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 16s 83ms/step - loss: 0.0942 - accuracy: 0.9601 - val_loss: 0.1001 - val_accuracy: 0.9518
# Epoch 5/16
# 192/192 [==============================] - 13s 69ms/step - loss: 0.0897 - accuracy: 0.9602 - val_loss: 0.1001 - val_accuracy: 0.9492
# Epoch 6/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0809 - accuracy: 0.9641
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 17s 87ms/step - loss: 0.0809 - accuracy: 0.9641 - val_loss: 0.0971 - val_accuracy: 0.9524
# Epoch 7/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9681
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 17s 87ms/step - loss: 0.0742 - accuracy: 0.9681 - val_loss: 0.1001 - val_accuracy: 0.9557
# Epoch 8/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9692
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 17s 87ms/step - loss: 0.0716 - accuracy: 0.9692 - val_loss: 0.0856 - val_accuracy: 0.9628
# Epoch 9/16
# 192/192 [==============================] - 13s 70ms/step - loss: 0.0695 - accuracy: 0.9681 - val_loss: 0.0919 - val_accuracy: 0.9589
# Epoch 10/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9734
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 17s 88ms/step - loss: 0.0627 - accuracy: 0.9734 - val_loss: 0.0823 - val_accuracy: 0.9635
# Epoch 11/16
# 192/192 [==============================] - 13s 69ms/step - loss: 0.0602 - accuracy: 0.9736 - val_loss: 0.0945 - val_accuracy: 0.9596
# Epoch 12/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9744
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 16s 86ms/step - loss: 0.0613 - accuracy: 0.9744 - val_loss: 0.0827 - val_accuracy: 0.9654
# Epoch 13/16
# 192/192 [==============================] - 13s 70ms/step - loss: 0.0588 - accuracy: 0.9754 - val_loss: 0.0838 - val_accuracy: 0.9628
# Epoch 14/16
# 192/192 [==============================] - 13s 69ms/step - loss: 0.0525 - accuracy: 0.9786 - val_loss: 0.0877 - val_accuracy: 0.9648
# Epoch 15/16
# 192/192 [==============================] - 13s 70ms/step - loss: 0.0527 - accuracy: 0.9765 - val_loss: 0.0847 - val_accuracy: 0.9609
# Epoch 15: early stopping

# %%
model_4.load_weights('weight_best.tf/')

# %%
model_4.evaluate(test_text,test_label)
# Out:
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0827 - accuracy: 0.9654
# [0.082698293030262, 0.9654498100280762]

# %%
plot_model(model_4)

# %%
pred_gru = np.squeeze(np.round(model_4.predict(test_text)))
score_model(test_label,pred_gru)
# Out:
# 48/48 [==============================] - 2s 22ms/step
# {'accuracy': 96.54498044328554,
#  'precision': 0.9656058230490463,
#  'recall': 0.9654498044328553,
#  'f1': 0.9654076208878193}

# %%
ebd_5 = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding_5'
)

# %%
inputs = layers.Input(shape=(205,128))
lay = layers.Bidirectional(layers.GRU(64,return_sequences=True))(inputs)
lay = layers.GlobalMaxPool1D()(lay)
lay = layers.Dropout(0.5)(lay)
lay = layers.Dense(32,activation='relu')(lay)
outputs = layers.Dense(1,activation='sigmoid')(lay)
model_5 = Model(inputs,outputs,name='model_5_bi-gru')

# %%
model_5.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model_5.summary()
# Out:
# Model: "model_5_bi-gru"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 205, 128)]        0
#
#  bidirectional_1 (Bidirectio  (None, 205, 128)         74496
#  nal)
#
#  global_max_pooling1d_4 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 32)                4128
#
#  dense_10 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 78,657
# Trainable params: 78,657
# Non-trainable params: 0
# _________________________________________________________________

# %%
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
model_5.fit(
    train_text,
    train_label,
    epochs=16,
    validation_data=(test_text,test_label),
    callbacks=[max_mod,
              early_stop])
# Out:
# Epoch 1/16
# 192/192 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.8758
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 36s 172ms/step - loss: 0.2652 - accuracy: 0.8758 - val_loss: 0.1220 - val_accuracy: 0.9439
# Epoch 2/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9431
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 33s 171ms/step - loss: 0.1207 - accuracy: 0.9431 - val_loss: 0.1043 - val_accuracy: 0.9498
# Epoch 3/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9552
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 34s 180ms/step - loss: 0.1005 - accuracy: 0.9552 - val_loss: 0.0945 - val_accuracy: 0.9524
# Epoch 4/16
# 192/192 [==============================] - 24s 128ms/step - loss: 0.0939 - accuracy: 0.9575 - val_loss: 0.1099 - val_accuracy: 0.9492
# Epoch 5/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9591
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 34s 176ms/step - loss: 0.0883 - accuracy: 0.9591 - val_loss: 0.0894 - val_accuracy: 0.9570
# Epoch 6/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9646
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 34s 179ms/step - loss: 0.0794 - accuracy: 0.9646 - val_loss: 0.0863 - val_accuracy: 0.9596
# Epoch 7/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9664
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 34s 176ms/step - loss: 0.0768 - accuracy: 0.9664 - val_loss: 0.0794 - val_accuracy: 0.9628
# Epoch 8/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9713
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 34s 177ms/step - loss: 0.0696 - accuracy: 0.9713 - val_loss: 0.0852 - val_accuracy: 0.9641
# Epoch 9/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9710
# WARNING:absl:Found untraced functions such as gru_cell_2_layer_call_fn, gru_cell_2_layer_call_and_return_conditional_losses, gru_cell_3_layer_call_fn, gru_cell_3_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 35s 181ms/step - loss: 0.0678 - accuracy: 0.9710 - val_loss: 0.0792 - val_accuracy: 0.9674
# Epoch 10/16
# 192/192 [==============================] - 25s 130ms/step - loss: 0.0616 - accuracy: 0.9739 - val_loss: 0.0932 - val_accuracy: 0.9589
# Epoch 11/16
# 192/192 [==============================] - 25s 130ms/step - loss: 0.0555 - accuracy: 0.9772 - val_loss: 0.0818 - val_accuracy: 0.9628
# Epoch 12/16
# 192/192 [==============================] - 33s 170ms/step - loss: 0.0606 - accuracy: 0.9744 - val_loss: 0.0831 - val_accuracy: 0.9609
# Epoch 12: early stopping

# %%
model_5.load_weights('weight_best.tf/')

# %%
model_5.evaluate(test_text,test_label)
# Out:
# 48/48 [==============================] - 2s 46ms/step - loss: 0.0792 - accuracy: 0.9674
# [0.07919137924909592, 0.9674054980278015]

# %%
plot_model(model_5)

# %%
pred_bigru = np.squeeze(np.round(model_5.predict(test_text)))
score_model(test_label,pred_bigru)
# Out:
# 48/48 [==============================] - 3s 46ms/step
# {'accuracy': 96.74054758800521,
#  'precision': 0.9674594478111088,
#  'recall': 0.9674054758800521,
#  'f1': 0.9674175498928113}

# %%
ebd_6 = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding_6'
)

# %%
from tensorflow.keras.models import Model
inputs = layers.Input(shape=(205,128))
lay = layers.Conv1D(64,kernel_size=5,padding='same',activation='relu')(inputs)
lay = layers.GlobalMaxPool1D()(lay)
lay = layers.Dense(32,activation='relu')(lay)
outputs = layers.Dense(1,activation='sigmoid')(lay)
model_6 = Model(inputs,outputs,name='model_6_conv1d')

# %%
model_6.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy'])

# %%
model_6.summary()
# Out:
# Model: "model_6_conv1d"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 205, 128)]        0
#
#  conv1d (Conv1D)             (None, 205, 64)           41024
#
#  global_max_pooling1d_5 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_11 (Dense)            (None, 32)                2080
#
#  dense_12 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 43,137
# Trainable params: 43,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
early_stop = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1,patience=3)
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
history = model_6.fit(
    train_text,
    train_label,
    epochs=16,
    validation_data=(test_text,test_label),
    callbacks=[max_mod,
              early_stop,])
# Out:
# Epoch 1/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1293 - accuracy: 0.9425
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 6s 23ms/step - loss: 0.1293 - accuracy: 0.9425 - val_loss: 0.0958 - val_accuracy: 0.9583
# Epoch 2/16
# 190/192 [============================>.] - ETA: 0s - loss: 0.0642 - accuracy: 0.9742
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 4s 20ms/step - loss: 0.0645 - accuracy: 0.9739 - val_loss: 0.0994 - val_accuracy: 0.9589
# Epoch 3/16
# 192/192 [==============================] - 3s 17ms/step - loss: 0.0544 - accuracy: 0.9804 - val_loss: 0.1279 - val_accuracy: 0.9524
# Epoch 4/16
# 192/192 [==============================] - 4s 23ms/step - loss: 0.0383 - accuracy: 0.9879 - val_loss: 0.1095 - val_accuracy: 0.9557
# Epoch 5/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9928
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 6s 32ms/step - loss: 0.0276 - accuracy: 0.9928 - val_loss: 0.0968 - val_accuracy: 0.9622
# Epoch 6/16
# 192/192 [==============================] - 3s 18ms/step - loss: 0.0246 - accuracy: 0.9930 - val_loss: 0.1248 - val_accuracy: 0.9615
# Epoch 7/16
# 192/192 [==============================] - 3s 17ms/step - loss: 0.0251 - accuracy: 0.9932 - val_loss: 0.1277 - val_accuracy: 0.9583
# Epoch 8/16
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.1385 - val_accuracy: 0.9583
# Epoch 8: early stopping

# %%
model_6.load_weights('weight_best.tf/')

# %%
model_6.evaluate(test_text,test_label)
# Out:
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0968 - accuracy: 0.9622
# [0.09681528806686401, 0.9621903300285339]

# %%
plot_model(model_6)

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
pred_conv1d = np.squeeze(np.round(model_6.predict(test_text)))
score_model(test_label,pred_conv1d)
# Out:
# 48/48 [==============================] - 0s 7ms/step
# {'accuracy': 96.21903520208605,
#  'precision': 0.9621903520208605,
#  'recall': 0.9621903520208605,
#  'f1': 0.9621903520208605}

# %%
coba = text_preprocessing('''Hasil Periksa Fakta Dyah Febriyani

Faktanya video tersebut merupakan acara Reuni 212 pada tahun 2022. Tidak ditemukan dalam video pernyataan yang menyebut Anies Baswedan didukung oleh orde baru.

============
[KATEGORI]

Konten yang menyesatkan

===========
[SUMBER]

Instagram
https://archive.cob.web.id/archive/1687284102.451279/singlefile.html

==========
[NARASI]

“Ada ORBA di belakang Anies”

===============
[PENJELASAN]

Sebuah akun Instagram mengunggah video dengan klaim ada Order Baru di belakang Anies Baswedan. Video itu memperlihatkan Titiek Soeharto memberikan sambutan acara. Titiek terlihat menyebutkan anggota keluarganya yang turut hadir dalam acara.

Berdasarkan penelusuran Google Lens, acara pada video tersebut merupakan kegiatan Reuni 212 di Masjid At-Tin Jakarta Timur pada Desember 2022 lalu. Tak hanya Titiek dan Rizieq, beberapa tokoh lainnya juga tampak hadir pada Reuni 212. Di antaranya Ketua Umum PA 212 Abdul Qohar, Ketum GNPF Ulama Yusuf Martak hingga Ketum Front Persaudaraan Islam Muhammad Alatas.

Tidak ditemukan dalam video sebuah pernyataan bahwa Anies Baswedan didukung oleh orde baru. Unggahan tersebut termasuk dalam konten yang menyesatkan.

=============
[REFERENSI]

https://youtu.be/raaqertws4g

https://www.cnnindonesia.com/nasional/20221202030251-20-881691/rizieq-shihab-hingga-titiek-soeharto-hadiri-reuni-212
''')
coba
# Out:
# 'hasil periksa fakta dyah febriyani fakta video rupa acara reuni @ @ temu video nyata anies baswedan dukung orde kategori konten sesat sumber instagram archive cob web id narasi orba anies buah akun instagram unggah video klaim order anies baswedan video lihat titiek soeharto sambut acara titiek lihat anggota keluarga hadir acara dasar telusur google lens acara video rupa giat reuni @ masjid at-tin jakarta timur desember @ titiek rizieq tokoh hadir reuni @ ketua pa @ abdul qohar tum gnpf ulama yusuf martak tum front saudara islam muhammad alatas temu video buah nyata anies baswedan dukung orde unggah masuk konten sesat referensi youtu be www cnnindonesia com'

# %%
np.array(['gg']).shape
# Out:
# (1,)

# %%
def word_processing(txt):
    txt = text_preprocessing(txt)
    txt = np.array([[y for y in x] for x in txt.split()])
    if txt != []:
        txt = np.hstack(txt)
    txt = ' '.join(txt)
    return txt

# %%
word_processing('''Hasil Periksa Fakta Dyah Febriyani

Faktanya video tersebut merupakan acara Reuni 212 pada tahun 2022. Tidak ditemukan dalam video pernyataan yang menyebut Anies Baswedan didukung oleh orde baru.

============
[KATEGORI]

Konten yang menyesatkan

===========
[SUMBER]

Instagram
https://archive.cob.web.id/archive/1687284102.451279/singlefile.html

==========
[NARASI]

“Ada ORBA di belakang Anies”

===============
[PENJELASAN]

Sebuah akun Instagram mengunggah video dengan klaim ada Order Baru di belakang Anies Baswedan. Video itu memperlihatkan Titiek Soeharto memberikan sambutan acara. Titiek terlihat menyebutkan anggota keluarganya yang turut hadir dalam acara.

Berdasarkan penelusuran Google Lens, acara pada video tersebut merupakan kegiatan Reuni 212 di Masjid At-Tin Jakarta Timur pada Desember 2022 lalu. Tak hanya Titiek dan Rizieq, beberapa tokoh lainnya juga tampak hadir pada Reuni 212. Di antaranya Ketua Umum PA 212 Abdul Qohar, Ketum GNPF Ulama Yusuf Martak hingga Ketum Front Persaudaraan Islam Muhammad Alatas.

Tidak ditemukan dalam video sebuah pernyataan bahwa Anies Baswedan didukung oleh orde baru. Unggahan tersebut termasuk dalam konten yang menyesatkan.

=============
[REFERENSI]

https://youtu.be/raaqertws4g

https://www.cnnindonesia.com/nasional/20221202030251-20-881691/rizieq-shihab-hingga-titiek-soeharto-hadiri-reuni-212
''')
# Out:
# 'h a s i l p e r i k s a f a k t a d y a h f e b r i y a n i f a k t a v i d e o r u p a a c a r a r e u n i @ @ t e m u v i d e o n y a t a a n i e s b a s w e d a n d u k u n g o r d e k a t e g o r i k o n t e n s e s a t s u m b e r i n s t a g r a m a r c h i v e c o b w e b i d n a r a s i o r b a a n i e s b u a h a k u n i n s t a g r a m u n g g a h v i d e o k l a i m o r d e r a n i e s b a s w e d a n v i d e o l i h a t t i t i e k s o e h a r t o s a m b u t a c a r a t i t i e k l i h a t a n g g o t a k e l u a r g a h a d i r a c a r a d a s a r t e l u s u r g o o g l e l e n s a c a r a v i d e o r u p a g i a t r e u n i @ m a s j i d a t - t i n j a k a r t a t i m u r d e s e m b e r @ t i t i e k r i z i e q t o k o h h a d i r r e u n i @ k e t u a p a @ a b d u l q o h a r t u m g n p f u l a m a y u s u f m a r t a k t u m f r o n t s a u d a r a i s l a m m u h a m m a d a l a t a s t e m u v i d e o b u a h n y a t a a n i e s b a s w e d a n d u k u n g o r d e u n g g a h m a s u k k o n t e n s e s a t r e f e r e n s i y o u t u b e w w w c n n i n d o n e s i a c o m'

# %%
char_text = raw_final['text'].apply(word_processing)

# %%
print(seed)
train_char_text, test_char_text, train_label, test_label = train_test_split(char_text, target, test_size=0.2, random_state=seed)
# Out:
# 50

# %%
avg_char = int(np.percentile([len(x.split()) for x in char_text],95))
tvx_char = TextVectorization(
    output_sequence_length=avg_char,
    standardize=None,
)
tvx_char.adapt(train_char_text)
ebd_char = Embedding(
    input_dim=len(tvx_char.get_vocabulary()),
    output_dim=32,
    mask_zero=False,
    name = 'embedding_char'
)

# %%
prep = [x.split() for x in train_char_text]
w2v_char = gensim.models.word2vec.Word2Vec(prep,min_count=5,vector_size=32,window=11)

# %%
w2v_char.wv[char_text[3543].split()]
# Out:
# array([[ 0.05934645, -0.2799792 , -0.38140142, ..., -0.24943565,
#          0.41478202,  0.5169741 ],
#        [ 0.37541378,  0.17393209, -0.01773748, ...,  0.02119955,
#         -0.47763273, -0.02379468],
#        [-0.99588674, -0.04066035,  0.31490847, ...,  0.13394651,
#         -0.30578116,  0.05426364],
#        ...,
#        [ 0.4600624 ,  0.46330073, -0.44062546, ...,  0.19613916,
#         -0.41923633,  0.78945506],
#        [ 0.6660148 ,  1.3236603 , -0.6292967 , ...,  1.0400094 ,
#         -0.18729039,  0.30475947],
#        [-0.7118093 , -0.16960624, -0.02770481, ...,  0.10019834,
#          0.31644097, -0.48294353]], dtype=float32)

# %%
def vectorize_char(sentence):
    vectorized=[]
    words = sentence.split()
    for word in words:
        if word in w2v_char.wv:
            vectorized.append(w2v_char.wv[word])
        else:
            vectorized.append(np.zeros(32))
    return np.array(vectorized)

# %%
def padding_char(text):
    padded=[]
    for i,v in enumerate(text):
        vector=[]
        if len(v) < 406:
            pdc = 406 - len(v)
            pad = np.zeros((pdc,32))
            vector = np.append(v,pad,axis=0)
        else:
            vector = v[:406]
        padded.append(vector)
    return np.array(padded)

# %%
train_char_text1 = train_char_text.apply(vectorize_char)
test_char_text1 = test_char_text.apply(vectorize_char)

# %%
train_char_text1 = padding_char(train_char_text1)
test_char_text1 = padding_char(test_char_text1)

# %%
train_char_text1.shape
# Out:
# (6135, 406, 32)

# %%
train_char_text1 = tf.convert_to_tensor(train_char_text1)
test_char_text1 = tf.convert_to_tensor(test_char_text1)

# %%
train_char_text1
# Out:
# <tf.Tensor: shape=(6135, 406, 32), dtype=float64, numpy=
# array([[[-0.02897104, -2.82734251,  1.75888312, ..., -0.48335761,
#           0.28227299, -0.43458024],
#         [ 0.37541378,  0.17393209, -0.01773748, ...,  0.02119955,
#          -0.47763273, -0.02379468],
#         [-0.16781412,  0.30619946, -0.22234116, ..., -0.36512581,
#           0.18078429, -0.22026385],
#         ...,
#         [-0.22301368, -0.32576767,  0.10632388, ..., -0.52705485,
#          -0.02173074, -1.10640895],
#         [-0.25040895, -0.50160861, -0.48744789, ...,  0.2424082 ,
#          -0.11327662, -0.59951156],
#         [-0.06367166,  0.58695471, -0.36525437, ...,  0.4500888 ,
#          -0.163992  ,  0.73004705]],
#
#        [[-0.02897104, -2.82734251,  1.75888312, ..., -0.48335761,
#           0.28227299, -0.43458024],
#         [ 0.37541378,  0.17393209, -0.01773748, ...,  0.02119955,
#          -0.47763273, -0.02379468],
#         [-0.16781412,  0.30619946, -0.22234116, ..., -0.36512581,
#           0.18078429, -0.22026385],
#         ...,
#         [ 0.24095581, -0.23051371, -0.92504609, ..., -0.33283734,
#          -0.07471547, -0.18767428],
#         [-0.61194593, -0.61005294,  1.26337492, ...,  1.80204761,
#          -1.1074214 ,  2.24948645],
#         [-0.06367166,  0.58695471, -0.36525437, ...,  0.4500888 ,
#          -0.163992  ,  0.73004705]],
#
#        [[-0.71180928, -0.16960624, -0.02770481, ...,  0.10019834,
#           0.31644097, -0.48294353],
#         [-0.0633084 ,  0.92650473, -0.08542095, ...,  0.37865987,
#          -0.2519891 ,  0.45635223],
#         [-0.18348509, -0.57732904,  0.9878341 , ...,  0.38551638,
#          -0.62219191,  0.51978797],
#         ...,
#         [-0.0633084 ,  0.92650473, -0.08542095, ...,  0.37865987,
#          -0.2519891 ,  0.45635223],
#         [-0.25040895, -0.50160861, -0.48744789, ...,  0.2424082 ,
#          -0.11327662, -0.59951156],
#         [-0.13441949, -0.53353631, -0.39987293, ..., -0.22209725,
#          -0.80727828,  0.11696143]],
#
#        ...,
#
#        [[ 0.23359498,  0.05288209, -0.11729262, ..., -1.29113877,
#          -0.17461589, -0.23076294],
#         [-0.1944675 ,  0.24037904, -0.35170823, ..., -0.08479068,
#          -0.10038788, -0.47067711],
#         [ 0.23359498,  0.05288209, -0.11729262, ..., -1.29113877,
#          -0.17461589, -0.23076294],
#         ...,
#         [ 0.66601479,  1.32366025, -0.62929672, ...,  1.04000938,
#          -0.18729039,  0.30475947],
#         [-0.99588674, -0.04066035,  0.31490847, ...,  0.13394651,
#          -0.30578116,  0.05426364],
#         [-0.06367166,  0.58695471, -0.36525437, ...,  0.4500888 ,
#          -0.163992  ,  0.73004705]],
#
#        [[-0.16781412,  0.30619946, -0.22234116, ..., -0.36512581,
#           0.18078429, -0.22026385],
#         [ 0.37541378,  0.17393209, -0.01773748, ...,  0.02119955,
#          -0.47763273, -0.02379468],
#         [-0.22301368, -0.32576767,  0.10632388, ..., -0.52705485,
#          -0.02173074, -1.10640895],
#         ...,
#         [ 0.7629742 , -0.55379719, -1.52629268, ..., -0.65617931,
#          -0.01769619,  0.31900039],
#         [ 0.37541378,  0.17393209, -0.01773748, ...,  0.02119955,
#          -0.47763273, -0.02379468],
#         [ 0.24095581, -0.23051371, -0.92504609, ..., -0.33283734,
#          -0.07471547, -0.18767428]],
#
#        [[-0.02897104, -2.82734251,  1.75888312, ..., -0.48335761,
#           0.28227299, -0.43458024],
#         [ 0.37541378,  0.17393209, -0.01773748, ...,  0.02119955,
#          -0.47763273, -0.02379468],
#         [-0.16781412,  0.30619946, -0.22234116, ..., -0.36512581,
#           0.18078429, -0.22026385],
#         ...,
#         [-0.25040895, -0.50160861, -0.48744789, ...,  0.2424082 ,
#          -0.11327662, -0.59951156],
#         [-0.06462933, -0.9858644 , -0.37706113, ..., -0.52520651,
#          -0.04909566, -0.23705934],
#         [ 0.37541378,  0.17393209, -0.01773748, ...,  0.02119955,
#          -0.47763273, -0.02379468]]])>

# %%
# char_vocab = tvx_char.get_vocabulary()
# char_vocab

# %%
inputs = layers.Input(shape=(406,32))
lay = layers.Conv1D(64,kernel_size=5,padding='same',activation='relu')(inputs)
lay = layers.Dropout(0.5)(lay)
lay = layers.GlobalMaxPool1D()(lay)
outputs = layers.Dense(1,activation='sigmoid')(lay)
model_char = Model(inputs,outputs,name='model_char')

# %%
model_char.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
model_char.fit(
    train_char_text1,
    train_label,
    epochs=24,
    validation_data=(test_char_text1,test_label),
    callbacks=[max_mod,
              early_stop])
# Out:
# Epoch 1/24
# 192/192 [==============================] - ETA: 0s - loss: 0.3627 - accuracy: 0.8406
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 6s 26ms/step - loss: 0.3627 - accuracy: 0.8406 - val_loss: 0.2688 - val_accuracy: 0.9048
# Epoch 2/24
# 191/192 [============================>.] - ETA: 0s - loss: 0.2384 - accuracy: 0.8950
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 5s 25ms/step - loss: 0.2391 - accuracy: 0.8949 - val_loss: 0.2260 - val_accuracy: 0.9120
# Epoch 3/24
# 190/192 [============================>.] - ETA: 0s - loss: 0.2116 - accuracy: 0.9092
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 5s 25ms/step - loss: 0.2115 - accuracy: 0.9090 - val_loss: 0.2080 - val_accuracy: 0.9146
# Epoch 4/24
# 192/192 [==============================] - ETA: 0s - loss: 0.1885 - accuracy: 0.9219
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 5s 24ms/step - loss: 0.1885 - accuracy: 0.9219 - val_loss: 0.1926 - val_accuracy: 0.9237
# Epoch 5/24
# 192/192 [==============================] - 4s 21ms/step - loss: 0.1763 - accuracy: 0.9267 - val_loss: 0.1832 - val_accuracy: 0.9205
# Epoch 6/24
# 192/192 [==============================] - 4s 20ms/step - loss: 0.1617 - accuracy: 0.9340 - val_loss: 0.1819 - val_accuracy: 0.9198
# Epoch 7/24
# 190/192 [============================>.] - ETA: 0s - loss: 0.1607 - accuracy: 0.9319
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 11s 58ms/step - loss: 0.1603 - accuracy: 0.9322 - val_loss: 0.1687 - val_accuracy: 0.9296
# Epoch 8/24
# 190/192 [============================>.] - ETA: 0s - loss: 0.1489 - accuracy: 0.9378
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 7s 37ms/step - loss: 0.1498 - accuracy: 0.9374 - val_loss: 0.1643 - val_accuracy: 0.9355
# Epoch 9/24
# 192/192 [==============================] - 5s 24ms/step - loss: 0.1442 - accuracy: 0.9418 - val_loss: 0.1599 - val_accuracy: 0.9355
# Epoch 10/24
# 192/192 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9430
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 5s 27ms/step - loss: 0.1409 - accuracy: 0.9430 - val_loss: 0.1598 - val_accuracy: 0.9368
# Epoch 11/24
# 192/192 [==============================] - 5s 24ms/step - loss: 0.1381 - accuracy: 0.9441 - val_loss: 0.1616 - val_accuracy: 0.9316
# Epoch 12/24
# 192/192 [==============================] - 5s 24ms/step - loss: 0.1354 - accuracy: 0.9441 - val_loss: 0.1586 - val_accuracy: 0.9283
# Epoch 13/24
# 192/192 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9495
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 5s 27ms/step - loss: 0.1265 - accuracy: 0.9495 - val_loss: 0.1476 - val_accuracy: 0.9387
# Epoch 14/24
# 192/192 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9449
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 5s 28ms/step - loss: 0.1317 - accuracy: 0.9449 - val_loss: 0.1458 - val_accuracy: 0.9413
# Epoch 15/24
# 192/192 [==============================] - 5s 25ms/step - loss: 0.1211 - accuracy: 0.9493 - val_loss: 0.1537 - val_accuracy: 0.9302
# Epoch 16/24
# 192/192 [==============================] - 5s 24ms/step - loss: 0.1177 - accuracy: 0.9487 - val_loss: 0.1438 - val_accuracy: 0.9381
# Epoch 17/24
# 192/192 [==============================] - 5s 24ms/step - loss: 0.1238 - accuracy: 0.9480 - val_loss: 0.1429 - val_accuracy: 0.9400
# Epoch 17: early stopping

# %%
model_char.load_weights('weight_best.tf/')

# %%
model_char.evaluate(test_char_text1,test_label)
# Out:
# 48/48 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9413
# [0.14576296508312225, 0.941329836845398]

# %%
plot_model(model_char)

# %%
pred_char = np.squeeze(np.round(model_char.predict(test_char_text1)))
score_model(test_label,pred_char)
# Out:
# 48/48 [==============================] - 0s 4ms/step
# {'accuracy': 94.13298565840938,
#  'precision': 0.9415153295205446,
#  'recall': 0.9413298565840938,
#  'f1': 0.9413647622727013}

# %%
raw_final['kata'] = [len(x.split()) for x in text]
def kalimat(txt):
    txt = re.sub(r'=+','',txt)
    txt = re.sub(r'http[^ \n]+','',txt)
    leng = len(re.findall(r'[^\n.]+',txt))
    return leng
raw_final['kalimat'] = [kalimat(x) for x in raw_final['text']]
raw_final
# Out:
#                                                    text  target  kata  \
# 0     Foto: Kumparan.com Debunk ini berisi iKlarifik...       1   286
# 1     Foto Ilustrasi Perkosaan Debunk ini berisi kla...       1   166
# 2     Debunk ini berisi klarifikasi dari PT Ultrajay...       1   308
# 3     foto: tribunnews.com Debunk ini berisi Klrifik...       1   187
# 4     Foto: tribunnews.com (Jokowi sedang memantau l...       1   193
# ...                                                 ...     ...   ...
# 7664  \nJakarta - Polri mewajibkan pembuat SIM harus...       1   203
# 7665  \nJakarta - Wakil Ketua MPR RI Lestari Moerdij...       1   203
# 7666  \nJakarta - Sebanyak 19 pelaku Usaha Mikro Kec...       1   444
# 7667  \nJakarta - Dewan Pengawas (Dewas) KPK menemuk...       1   145
# 7668  \nJakarta - Seorang pria bernama Rifkho Achmad...       1   268
#
#       kalimat  angka  link
# 0          31     15     4
# 1          17      1     1
# 2          25      3     3
# 3          23      9     1
# 4          21      9     4
# ...       ...    ...   ...
# 7664       31      6     0
# 7665       22      6     0
# 7666       40     11     0
# 7667       22      5     0
# 7668       39     11     0
#
# [7669 rows x 6 columns]

# %%
raw_final['angka'] = [len(re.findall('@',x)) for x in text]
raw_final['link'] = [len(re.findall(r'http[^ \n]+',x)) for x in raw_final['text']]
raw_final
# Out:
#                                                    text  target  kata  \
# 0     Foto: Kumparan.com Debunk ini berisi iKlarifik...       1   286
# 1     Foto Ilustrasi Perkosaan Debunk ini berisi kla...       1   166
# 2     Debunk ini berisi klarifikasi dari PT Ultrajay...       1   308
# 3     foto: tribunnews.com Debunk ini berisi Klrifik...       1   187
# 4     Foto: tribunnews.com (Jokowi sedang memantau l...       1   193
# ...                                                 ...     ...   ...
# 7664  \nJakarta - Polri mewajibkan pembuat SIM harus...       1   203
# 7665  \nJakarta - Wakil Ketua MPR RI Lestari Moerdij...       1   203
# 7666  \nJakarta - Sebanyak 19 pelaku Usaha Mikro Kec...       1   444
# 7667  \nJakarta - Dewan Pengawas (Dewas) KPK menemuk...       1   145
# 7668  \nJakarta - Seorang pria bernama Rifkho Achmad...       1   268
#
#       kalimat  angka  link
# 0          31     31     4
# 1          17      2     1
# 2          25      7     3
# 3          23     18     1
# 4          21     19     4
# ...       ...    ...   ...
# 7664       31     12     0
# 7665       22     13     0
# 7666       40     23     0
# 7667       22     11     0
# 7668       39     23     0
#
# [7669 rows x 6 columns]

# %%
raw_final['kalimat'].value_counts()[100:]
# Out:
# 119    2
# 95     2
# 66     2
# 88     2
# 107    2
# 132    2
# 116    2
# 121    1
# 131    1
# 141    1
# 241    1
# 140    1
# 145    1
# 229    1
# 118    1
# 169    1
# 127    1
# 186    1
# 211    1
# 111    1
# 134    1
# 174    1
# 152    1
# 87     1
# 231    1
# 166    1
# 125    1
# 103    1
# 265    1
# 192    1
# 170    1
# 149    1
# 130    1
# 236    1
# 128    1
# 285    1
# 155    1
# 104    1
# 282    1
# 151    1
# 122    1
# 157    1
# 154    1
# 204    1
# 94     1
# 114    1
# Name: kalimat, dtype: int64

# %%
raw_final.corr()
# Out:
#            target      kata   kalimat     angka      link
# target   1.000000  0.194948  0.236393  0.220073 -0.366722
# kata     0.194948  1.000000  0.869450  0.702367  0.318353
# kalimat  0.236393  0.869450  1.000000  0.636415  0.318970
# angka    0.220073  0.702367  0.636415  1.000000  0.195363
# link    -0.366722  0.318353  0.318970  0.195363  1.000000

# %%
raw_final.corr()
# Out:
#            target      kata   kalimat     angka      link
# target   1.000000  0.194948  0.236393  0.220073 -0.366722
# kata     0.194948  1.000000  0.869450  0.702367  0.318353
# kalimat  0.236393  0.869450  1.000000  0.636415  0.318970
# angka    0.220073  0.702367  0.636415  1.000000  0.195363
# link    -0.366722  0.318353  0.318970  0.195363  1.000000

# %%
raw_final.hist(bins=30,figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'target'}>,
#         <Axes: title={'center': 'kata'}>],
#        [<Axes: title={'center': 'kalimat'}>,
#         <Axes: title={'center': 'angka'}>],
#        [<Axes: title={'center': 'link'}>, <Axes: >]], dtype=object)

# %%
sns.pairplot(raw_final)

# %%
raw_final[raw_final['kata'] <= 759]['kata'].hist(bins=30)
# Out:
# <Axes: >

# %%
raw_final[raw_final['kalimat'] < 60]['kalimat'].hist()
# Out:
# <Axes: >

# %%
raw_final[raw_final['kalimat'] <= 6]['kalimat'].value_counts()
# Out:
# 1    170
# 6     70
# 5     69
# 4     67
# 3     59
# 2     36
# Name: kalimat, dtype: int64

# %%
np.percentile(raw_final['kalimat'],95),np.percentile(raw_final['kata'],95),np.percentile(raw_final['angka'],95),np.percentile(raw_final['link'],95)
# Out:
# (52.0, 405.59999999999945, 35.0, 6.0)

# %%
thre = np.arange(0,411,10)
for x in range(len(thre)-1):
    raw_final['kata'] = [x if y>thre[x] and y<=thre[x+1] else y for y in raw_final['kata']]
raw_final['kata'] = [41 if y>410 else y for y in raw_final['kata']]
raw_final['kata'].value_counts()
# Out:
# 14    493
# 15    466
# 16    442
# 17    433
# 13    419
# 18    384
# 41    363
# 12    360
# 19    353
# 20    313
# 11    298
# 21    293
# 22    246
# 24    229
# 10    228
# 23    200
# 25    191
# 9     156
# 27    140
# 26    136
# 28    131
# 0     113
# 8     112
# 30    102
# 29    100
# 32     91
# 7      82
# 5      78
# 31     74
# 33     67
# 6      67
# 34     67
# 4      58
# 3      52
# 38     52
# 1      49
# 2      45
# 35     43
# 36     42
# 39     40
# 37     31
# 40     30
# Name: kata, dtype: int64

# %%
raw_final['kalimat'] = [0 if x == 1 else x for x in raw_final['kalimat']]
thre = np.arange(1,62,5)
for x in range(len(thre)-1):
    raw_final['kalimat'] = [x+1 if y>thre[x] and y<=thre[x+1] else y for y in raw_final['kalimat']]
raw_final['kalimat'] = [12 if y>60 else y for y in raw_final['kalimat']]
raw_final['kalimat'].value_counts()
# Out:
# 4     1572
# 5     1519
# 6     1065
# 3      907
# 7      631
# 2      373
# 8      367
# 1      301
# 12     279
# 9      224
# 0      170
# 10     147
# 11     114
# Name: kalimat, dtype: int64

# %%
thre = np.arange(1,37,2)
for x in range(len(thre)-1):
    raw_final['angka'] = [x+1 if y>thre[x] and y<=thre[x+1] else y for y in raw_final['angka']]
raw_final['angka'] = [18 if y>35 else y for y in raw_final['angka']]
raw_final['angka'].value_counts()
# Out:
# 1     1045
# 3      964
# 2      848
# 4      818
# 5      633
# 6      529
# 0      501
# 7      430
# 18     372
# 8      327
# 9      294
# 10     237
# 11     192
# 12     143
# 13     109
# 14      76
# 15      64
# 17      47
# 16      40
# Name: angka, dtype: int64

# %%
raw_final['link'] = [16 if y>15 else y for y in raw_final['link']]
raw_final['link'].value_counts()
# Out:
# 0     3128
# 2     1376
# 3     1076
# 4      670
# 1      569
# 5      340
# 6      159
# 7       80
# 9       57
# 8       45
# 11      44
# 13      42
# 10      23
# 12      21
# 16      16
# 15      13
# 14      10
# Name: link, dtype: int64

# %%
kata = pd.DataFrame(tf.one_hot(raw_final['kata'],depth=42))
kalimat = pd.DataFrame(tf.one_hot(raw_final['kalimat'],depth=13))
link = pd.DataFrame(tf.one_hot(raw_final['link'],depth=16))
angka = pd.DataFrame(tf.one_hot(raw_final['angka'],depth=19))

# %%
len(kata),len(target)
# Out:
# (7669, 7669)

# %%
train_kalimat, test_kalimat, train_label, test_label = train_test_split(kalimat, target, test_size=0.2, random_state=seed)
train_kata, test_kata, train_label, test_label = train_test_split(kata, target, test_size=0.2, random_state=seed)
train_angka, test_angka, train_label, test_label = train_test_split(angka, target, test_size=0.2, random_state=seed)
train_link, test_link, train_label, test_label = train_test_split(link, target, test_size=0.2, random_state=seed)

# %%
fit = raw_final[['kalimat','kata', 'angka', 'link','target']]
train_fit_text, test_fit_text, train_label, test_label = train_test_split(fit[['kalimat', 'angka','kata', 'link']], fit['target'], test_size=0.2, random_state=seed)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=500)
rfc.fit(train_fit_text,train_label)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
pred_rfc = rfc.predict(test_fit_text)
score_model(test_label,pred_rfc)
# Out:
# {'accuracy': 84.55019556714471,
#  'precision': 0.845805778392361,
#  'recall': 0.8455019556714471,
#  'f1': 0.8450414380547645}

# %%
ebd_hy = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding_hybrid'
)

# %%
#Token embedding
input_tok = layers.Input(shape=(205,128))
x = layers.Conv1D(64,kernel_size=3,padding='same',activation='relu')(input_tok)
x = layers.GlobalMaxPool1D()(x)
x = layers.Dense(32,activation='relu')(x)
token_model = Model(input_tok,x)

#Character embedding
input_char = layers.Input(shape=(1,),dtype='string')
y = tvx_char(input_char)
y = ebd_char(y)
y = layers.Conv1D(64,kernel_size=5,padding='same',activation='relu')(y)
y = layers.GlobalMaxPool1D()(y)
char_model = Model(input_char,y)

#Concatenate
token_char = layers.Concatenate(name='token_char_hybrid')([token_model.output,char_model.output])

#Avoid overfitting
z = layers.Dense(32,activation='relu')(token_char)
outputs = layers.Dense(1,activation='sigmoid')(z)

#Construct
hybrid_model = Model(inputs=[token_model.input,char_model.input],
                    outputs=outputs,
                    name='hybrid_model_token_char_embedding')

#Compile
hybrid_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy'])

# %%
hybrid_model.summary()
# Out:
# Model: "hybrid_model_token_char_embedding"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_43 (InputLayer)          [(None, 1)]          0           []
#
#  input_42 (InputLayer)          [(None, 205, 128)]   0           []
#
#  text_vectorization_3 (TextVect  (None, 2170)        0           ['input_43[0][0]']
#  orization)
#
#  conv1d_16 (Conv1D)             (None, 205, 64)      24640       ['input_42[0][0]']
#
#  embedding_char (Embedding)     (None, 2170, 32)     992         ['text_vectorization_3[0][0]']
#
#  global_max_pooling1d_21 (Globa  (None, 64)          0           ['conv1d_16[0][0]']
#  lMaxPooling1D)
#
#  conv1d_17 (Conv1D)             (None, 2170, 64)     10304       ['embedding_char[0][0]']
#
#  dense_64 (Dense)               (None, 32)           2080        ['global_max_pooling1d_21[0][0]']
#
#  global_max_pooling1d_22 (Globa  (None, 64)          0           ['conv1d_17[0][0]']
#  lMaxPooling1D)
#
#  token_char_hybrid (Concatenate  (None, 96)          0           ['dense_64[0][0]',
#  )                                                                'global_max_pooling1d_22[0][0]']
#
#  dense_65 (Dense)               (None, 32)           3104        ['token_char_hybrid[0][0]']
#
#  dense_66 (Dense)               (None, 1)            33          ['dense_65[0][0]']
#
# ==================================================================================================
# Total params: 41,153
# Trainable params: 41,153
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(hybrid_model)

# %%
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
history = hybrid_model.fit(
    [train_text, train_char_text],
    train_label,
    epochs=24,
    validation_data=([test_text, test_char_text],test_label),
    callbacks=[max_mod,
              early_stop])
# Out:
# Epoch 1/24
# 192/192 [==============================] - ETA: 0s - loss: 0.1614 - accuracy: 0.9234
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 18s 87ms/step - loss: 0.1614 - accuracy: 0.9234 - val_loss: 0.0948 - val_accuracy: 0.9563
# Epoch 2/24
# 192/192 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9619
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 16s 82ms/step - loss: 0.0855 - accuracy: 0.9619 - val_loss: 0.1052 - val_accuracy: 0.9596
# Epoch 3/24
# 192/192 [==============================] - ETA: 0s - loss: 0.0602 - accuracy: 0.9770
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 15s 80ms/step - loss: 0.0602 - accuracy: 0.9770 - val_loss: 0.1056 - val_accuracy: 0.9654
# Epoch 4/24
# 192/192 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9829
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 15s 80ms/step - loss: 0.0444 - accuracy: 0.9829 - val_loss: 0.0992 - val_accuracy: 0.9674
# Epoch 5/24
# 192/192 [==============================] - 14s 73ms/step - loss: 0.0433 - accuracy: 0.9855 - val_loss: 0.1450 - val_accuracy: 0.9478
# Epoch 6/24
# 192/192 [==============================] - 14s 74ms/step - loss: 0.0336 - accuracy: 0.9891 - val_loss: 0.1258 - val_accuracy: 0.9635
# Epoch 7/24
# 192/192 [==============================] - 14s 73ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.1433 - val_accuracy: 0.9518
# Epoch 7: early stopping

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
hybrid_model.load_weights('weight_best.tf/')

# %%
hybrid_model.evaluate([test_text, test_char_text],test_label)
# Out:
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0992 - accuracy: 0.9674
# [0.09921428561210632, 0.9674054980278015]

# %%
pred_hybrid = np.squeeze(np.round(hybrid_model.predict([test_text, test_char_text])))
score_model(test_label,pred_hybrid)
# Out:
# 48/48 [==============================] - 2s 24ms/step
# {'accuracy': 96.74054758800521,
#  'precision': 0.9674851171820805,
#  'recall': 0.9674054758800521,
#  'f1': 0.9674188551052281}

# %%
pred_hybrid = np.squeeze(np.round(hybrid_model.predict([train_text, train_char_text])))
score_model(train_label,pred_hybrid)
# Out:
# 192/192 [==============================] - 4s 20ms/step
# {'accuracy': 99.3643031784841,
#  'precision': 0.9936435274099101,
#  'recall': 0.993643031784841,
#  'f1': 0.993642615331553}

# %%
ebd_tribrid = Embedding(
    input_dim=max_vocab,
    output_dim=128,
    input_length=avg,
    name = 'embedding_tribrid'
)

# %%
#Token embedding
input_tok = layers.Input(shape=(205,128))
x = layers.Conv1D(64,kernel_size=3,padding='valid',activation='relu')(input_tok)
x = layers.Bidirectional(layers.LSTM(32,return_sequences=True))(x)
x = layers.GlobalMaxPool1D()(x)
x = layers.Dense(16,activation='relu')(x)
token_model = Model(input_tok,x)

#Character embedding
input_char = layers.Input(shape=(1,),dtype='string')
y = tvx_char(input_char)
y = ebd_char(y)
y = layers.Conv1D(64,kernel_size=11,padding='valid',activation='relu')(y)
y = layers.GlobalMaxPool1D()(y)
y = layers.Dense(32,activation='relu')(y)
char_model = Model(input_char,y)

#Kalimat
input_kal = layers.Input(shape=(13,),dtype='int32')
p = layers.Dense(32,activation='relu')(input_kal)
kalimat_model = Model(input_kal,p)

#Kata
input_kat = layers.Input(shape=(42,),dtype='int32')
q = layers.Dense(32,activation='relu')(input_kat)
kata_model = Model(input_kat,q)

#Angka
input_ang = layers.Input(shape=(19,),dtype='int32')
r = layers.Dense(32,activation='relu')(input_ang)
angka_model = Model(input_ang,r)

#Link
input_lin = layers.Input(shape=(16,),dtype='int32')
s = layers.Dense(32,activation='relu')(input_lin)
link_model = Model(input_lin,s)

#Concatenate
token_char = layers.Concatenate(name='token_char_hybrid')([token_model.output,char_model.output])

#Avoid overfitting
z = layers.Dense(32,activation='relu')(token_char)
z = layers.Dropout(0.2)(z)
z = layers.Dense(16,activation='relu')(z)

#Concatenate
tribrid_model = layers.Concatenate(name='multimodel_tribrid')([z,kalimat_model.output,kata_model.output, 
                                                               angka_model.output,link_model.output])

#Output
final = layers.Dense(16,activation='relu')(tribrid_model)
outputs = layers.Dense(1,activation='sigmoid')(final)

#Construct
tribrid_model = Model(inputs=[token_model.input,char_model.input,kalimat_model.input,kata_model.input,
                             angka_model.input,link_model.input],
                    outputs=outputs,
                    name='tribrid_multimodel_embedding')

#Compile
tribrid_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(),metrics=['accuracy'])

# %%
tribrid_model.summary()
# Out:
# Model: "tribrid_multimodel_embedding"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_76 (InputLayer)          [(None, 1)]          0           []
#
#  input_75 (InputLayer)          [(None, 205, 128)]   0           []
#
#  text_vectorization_3 (TextVect  (None, 2170)        0           ['input_76[0][0]']
#  orization)
#
#  conv1d_26 (Conv1D)             (None, 203, 64)      24640       ['input_75[0][0]']
#
#  embedding_char (Embedding)     (None, 2170, 32)     992         ['text_vectorization_3[5][0]']
#
#  bidirectional_16 (Bidirectiona  (None, 203, 64)     24832       ['conv1d_26[0][0]']
#  l)
#
#  conv1d_27 (Conv1D)             (None, 2160, 64)     22592       ['embedding_char[5][0]']
#
#  global_max_pooling1d_38 (Globa  (None, 64)          0           ['bidirectional_16[0][0]']
#  lMaxPooling1D)
#
#  global_max_pooling1d_39 (Globa  (None, 64)          0           ['conv1d_27[0][0]']
#  lMaxPooling1D)
#
#  dense_124 (Dense)              (None, 16)           1040        ['global_max_pooling1d_38[0][0]']
#
#  dense_125 (Dense)              (None, 32)           2080        ['global_max_pooling1d_39[0][0]']
#
#  token_char_hybrid (Concatenate  (None, 48)          0           ['dense_124[0][0]',
#  )                                                                'dense_125[0][0]']
#
#  dense_130 (Dense)              (None, 32)           1568        ['token_char_hybrid[0][0]']
#
#  dropout_6 (Dropout)            (None, 32)           0           ['dense_130[0][0]']
#
#  input_77 (InputLayer)          [(None, 13)]         0           []
#
#  input_78 (InputLayer)          [(None, 42)]         0           []
#
#  input_79 (InputLayer)          [(None, 19)]         0           []
#
#  input_80 (InputLayer)          [(None, 16)]         0           []
#
#  dense_131 (Dense)              (None, 16)           528         ['dropout_6[0][0]']
#
#  dense_126 (Dense)              (None, 32)           448         ['input_77[0][0]']
#
#  dense_127 (Dense)              (None, 32)           1376        ['input_78[0][0]']
#
#  dense_128 (Dense)              (None, 32)           640         ['input_79[0][0]']
#
#  dense_129 (Dense)              (None, 32)           544         ['input_80[0][0]']
#
#  multimodel_tribrid (Concatenat  (None, 144)         0           ['dense_131[0][0]',
#  e)                                                               'dense_126[0][0]',
#                                                                   'dense_127[0][0]',
#                                                                   'dense_128[0][0]',
#                                                                   'dense_129[0][0]']
#
#  dense_132 (Dense)              (None, 16)           2320        ['multimodel_tribrid[0][0]']
#
#  dense_133 (Dense)              (None, 1)            17          ['dense_132[0][0]']
#
# ==================================================================================================
# Total params: 83,617
# Trainable params: 83,617
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(tribrid_model)

# %%
max_mod = ModelCheckpoint(
    filepath='weight_best.tf',
    monitor='val_accuracy',
    mode='max',
    save_best_only=True
)
history = tribrid_model.fit(
    [train_text, train_char_text, train_kalimat, train_kata, train_angka, train_link],
    train_label,
    batch_size=32,
    epochs=16,
    validation_data=([test_text, test_char_text, test_kalimat, test_kata, test_angka, test_link],test_label),
    callbacks=[max_mod,
              early_stop])
# Out:
# Epoch 1/16
# 192/192 [==============================] - ETA: 0s - loss: 0.2637 - accuracy: 0.8776
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_47_layer_call_fn, lstm_cell_47_layer_call_and_return_conditional_losses, lstm_cell_48_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 131s 649ms/step - loss: 0.2637 - accuracy: 0.8776 - val_loss: 0.1221 - val_accuracy: 0.9446
# Epoch 2/16
# 192/192 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9548
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_47_layer_call_fn, lstm_cell_47_layer_call_and_return_conditional_losses, lstm_cell_48_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 106s 549ms/step - loss: 0.1002 - accuracy: 0.9548 - val_loss: 0.1163 - val_accuracy: 0.9472
# Epoch 3/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 0.9648
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_47_layer_call_fn, lstm_cell_47_layer_call_and_return_conditional_losses, lstm_cell_48_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 104s 539ms/step - loss: 0.0794 - accuracy: 0.9648 - val_loss: 0.1093 - val_accuracy: 0.9518
# Epoch 4/16
# 192/192 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9746
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, lstm_cell_47_layer_call_fn, lstm_cell_47_layer_call_and_return_conditional_losses, lstm_cell_48_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# INFO:tensorflow:Assets written to: weight_best.tf\assets
# 192/192 [==============================] - 120s 627ms/step - loss: 0.0607 - accuracy: 0.9746 - val_loss: 0.1076 - val_accuracy: 0.9570
# Epoch 5/16
# 192/192 [==============================] - 99s 517ms/step - loss: 0.0457 - accuracy: 0.9821 - val_loss: 0.1103 - val_accuracy: 0.9550
# Epoch 6/16
# 192/192 [==============================] - 103s 535ms/step - loss: 0.0282 - accuracy: 0.9910 - val_loss: 0.1835 - val_accuracy: 0.9439
# Epoch 7/16
# 192/192 [==============================] - 108s 562ms/step - loss: 0.0254 - accuracy: 0.9909 - val_loss: 0.1378 - val_accuracy: 0.9537
# Epoch 7: early stopping

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
tribrid_model.load_weights('weight_best.tf/')

# %%
tribrid_model.evaluate([test_text, test_char_text, test_kalimat, test_kata, test_angka, test_link],test_label)
# Out:
# 48/48 [==============================] - 10s 205ms/step - loss: 0.0792 - accuracy: 0.9713
# [0.0792388841509819, 0.9713168144226074]

# %%
pred_tribrid = np.squeeze(np.round(tribrid_model.predict([test_text, test_char_text, test_kalimat, test_kata, test_angka, test_link])))
score_model(test_label,pred_tribrid)
# Out:
# 48/48 [==============================] - 10s 211ms/step
# {'accuracy': 97.13168187744459,
#  'precision': 0.9715560507168073,
#  'recall': 0.9713168187744459,
#  'f1': 0.971302311102743}

# %%
pred_tribrid = np.squeeze(np.round(tribrid_model.predict([train_text, train_char_text, train_kalimat, train_kata, train_angka, train_link])))
score_model(train_label,pred_tribrid)
# Out:
# 192/192 [==============================] - 17s 90ms/step
# {'accuracy': 99.75550122249389,
#  'precision': 0.9975560257062808,
#  'recall': 0.9975550122249389,
#  'f1': 0.9975548520505972}

# %%
vocab = w2v.wv.key_to_index
wgt = w2v.syn1neg

# %%
w2v.wv.key_to_index
# Out:
# {'@': 0,
#  'video': 1,
#  'com': 2,
#  'laku': 3,
#  'indonesia': 4,
#  'orang': 5,
#  'jakarta': 6,
#  'hasil': 7,
#  'akun': 8,
#  'informasi': 9,
#  'salah': 10,
#  'rupa': 11,
#  'narasi': 12,
#  'sumber': 13,
#  'foto': 14,
#  'fakta': 15,
#  'kategori': 16,
#  'www': 17,
#  'referensi': 18,
#  'baca': 19,
#  'unggah': 20,
#  'konten': 21,
#  'kait': 22,
#  'facebook': 23,
#  'nyata': 24,
#  'edar': 25,
#  'milik': 26,
#  'masuk': 27,
#  'media': 28,
#  'buah': 29,
#  'id': 30,
#  'klaim': 31,
#  'nama': 32,
#  'presiden': 33,
#  'masyarakat': 34,
#  'kpk': 35,
#  'jalan': 36,
#  'temu': 37,
#  'jokowi': 38,
#  'periksa': 39,
#  'judul': 40,
#  'korban': 41,
#  'lihat': 42,
#  'berita': 43,
#  'to': 44,
#  'perintah': 45,
#  'artikel': 46,
#  'dasar': 47,
#  'sosial': 48,
#  'warga': 49,
#  'rumah': 50,
#  'the': 51,
#  'lengkap': 52,
#  'tulis': 53,
#  'negara': 54,
#  'anak': 55,
#  'klarifikasi': 56,
#  'polisi': 57,
#  'telusur': 58,
#  'isi': 59,
#  'menteri': 60,
#  'sesat': 61,
#  'kerja': 62,
#  'content': 63,
#  'kena': 64,
#  'hadap': 65,
#  'lapor': 66,
#  'resmi': 67,
#  'youtube': 68,
#  'terima': 69,
#  'twitter': 70,
#  'rp': 71,
#  'kota': 72,
#  'hukum': 73,
#  'archive': 74,
#  'dunia': 75,
#  '-': 76,
#  'gambar': 77,
#  'duga': 78,
#  'langsung': 79,
#  'ketua': 80,
#  'kepala': 81,
#  'tinggal': 82,
#  'air': 83,
#  'anggota': 84,
#  'surat': 85,
#  'terang': 86,
#  'lansir': 87,
#  'sehat': 88,
#  'advertisement': 89,
#  'scroll': 90,
#  'resume': 91,
#  'uang': 92,
#  'pesan': 93,
#  'hoax': 94,
#  'sakit': 95,
#  'kabar': 96,
#  'idul': 97,
#  'hubung': 98,
#  'makan': 99,
#  'tangkap': 100,
#  'a': 101,
#  'tanggal': 102,
#  'palsu': 103,
#  'kali': 104,
#  'adha': 105,
#  'sebar': 106,
#  'anies': 107,
#  'dki': 108,
#  'nomor': 109,
#  'whatsapp': 110,
#  'juni': 111,
#  'of': 112,
#  'usaha': 113,
#  'bangun': 114,
#  'instagram': 115,
#  'polri': 116,
#  'bukti': 117,
#  'co': 118,
#  'tahan': 119,
#  'yg': 120,
#  'aman': 121,
#  'nasional': 122,
#  'ly': 123,
#  'sesuai': 124,
#  'asli': 125,
#  'tugas': 126,
#  'bakar': 127,
#  'wakil': 128,
#  'bit': 129,
#  'hoaks': 130,
#  'dukung': 131,
#  'bantu': 132,
#  'barat': 133,
#  'masjid': 134,
#  'daerah': 135,
#  'atur': 136,
#  'tuju': 137,
#  'acara': 138,
#  'ph': 139,
#  'situs': 140,
#  'kandung': 141,
#  'raya': 142,
#  'proses': 143,
#  'data': 144,
#  'tindak': 145,
#  'tim': 146,
#  'jawa': 147,
#  'selasa': 148,
#  'isu': 149,
#  'pilih': 150,
#  'gambas': 151,
#  '@detik': 152,
#  'tangan': 153,
#  'jabat': 154,
#  'keluarga': 155,
#  'kondisi': 156,
#  'web': 157,
#  'partai': 158,
#  'prabowo': 159,
#  'bentuk': 160,
#  'politik': 161,
#  'pria': 162,
#  'ikan': 163,
#  'manipulasi': 164,
#  'selatan': 165,
#  'putus': 166,
#  'detik': 167,
#  'suara': 168,
#  'juta': 169,
#  'arsip': 170,
#  'kabupaten': 171,
#  'ri': 172,
#  'agama': 173,
#  'rabu': 174,
#  'senin': 175,
#  'bawa': 176,
#  'tingkat': 177,
#  'aksi': 178,
#  'layan': 179,
#  'ya': 180,
#  'kendara': 181,
#  'negeri': 182,
#  'hadir': 183,
#  'in': 184,
#  'ambil': 185,
#  'buka': 186,
#  'laksana': 187,
#  'lokasi': 188,
#  'pesawat': 189,
#  'and': 190,
#  'pusat': 191,
#  'kompas': 192,
#  'polda': 193,
#  'pt': 194,
#  'gubernur': 195,
#  'harga': 196,
#  'news': 197,
#  'nilai': 198,
#  'islam': 199,
#  'mobil': 200,
#  'vaksin': 201,
#  'akibat': 202,
#  'harap': 203,
#  'alami': 204,
#  'dpr': 205,
#  'beda': 206,
#  'desa': 207,
#  'pakai': 208,
#  'cari': 209,
#  'giat': 210,
#  'bahas': 211,
#  'sangka': 212,
#  'pimpin': 213,
#  'badan': 214,
#  'gempa': 215,
#  'kamis': 216,
#  'wib': 217,
#  'jumat': 218,
#  'cob': 219,
#  'peristiwa': 220,
#  'arah': 221,
#  'bunuh': 222,
#  'utama': 223,
#  'bahasa': 224,
#  'minggu': 225,
#  'haji': 226,
#  'konteks': 227,
#  'rutan': 228,
#  'khusus': 229,
#  'bicara': 230,
#  'tampil': 231,
#  'uji': 232,
#  'pidana': 233,
#  'dinas': 234,
#  'simak': 235,
#  'cadang': 236,
#  'tutup': 237,
#  'wilayah': 238,
#  'covid-@': 239,
#  'm': 240,
#  'postingan': 241,
#  'timur': 242,
#  'arti': 243,
#  'ban': 244,
#  'google': 245,
#  'sidang': 246,
#  'viral': 247,
#  'selamat': 248,
#  'sekolah': 249,
#  'korupsi': 250,
#  'ajar': 251,
#  'dana': 252,
#  'ribu': 253,
#  'langgar': 254,
#  'pasal': 255,
#  'metro': 256,
#  'kurban': 257,
#  'hidup': 258,
#  'serang': 259,
#  'bahan': 260,
#  'kutip': 261,
#  '@-@': 262,
#  'lele': 263,
#  'tni': 264,
#  'rencana': 265,
#  'mati': 266,
#  'turun': 267,
#  'bogor': 268,
#  'calon': 269,
#  'ganti': 270,
#  'kuat': 271,
#  'dr': 272,
#  'ubah': 273,
#  'obat': 274,
#  'baswedan': 275,
#  'pasang': 276,
#  'undang': 277,
#  'potong': 278,
#  'muncul': 279,
#  'ulang': 280,
#  'gelar': 281,
#  's': 282,
#  'kantor': 283,
#  'program': 284,
#  'darah': 285,
#  'maret': 286,
#  'pegawai': 287,
#  'didik': 288,
#  'dakwa': 289,
#  'jual': 290,
#  'utara': 291,
#  'manusia': 292,
#  'miliar': 293,
#  'jenis': 294,
#  'selesai': 295,
#  'joko': 296,
#  'layar': 297,
#  'malam': 298,
#  'papua': 299,
#  'april': 300,
#  'wanita': 301,
#  'china': 302,
#  'kirim': 303,
#  'jaksa': 304,
#  'jatuh': 305,
#  'mudah': 306,
#  'hati': 307,
#  'dokter': 308,
#  'januari': 309,
#  'tanah': 310,
#  'mohon': 311,
#  'widodo': 312,
#  'konfirmasi': 313,
#  'libur': 314,
#  'angkat': 315,
#  'jaga': 316,
#  'bank': 317,
#  'saksi': 318,
#  'kembang': 319,
#  'motor': 320,
#  'tubuh': 321,
#  'libat': 322,
#  'main': 323,
#  'cuti': 324,
#  'daftar': 325,
#  'berat': 326,
#  'produk': 327,
#  'tipu': 328,
#  'penuh': 329,
#  'coba': 330,
#  'bayar': 331,
#  'tanggap': 332,
#  'beli': 333,
#  'nggak': 334,
#  'lembaga': 335,
#  'camat': 336,
#  'is': 337,
#  'cuit': 338,
#  'on': 339,
#  'arab': 340,
#  'butuh': 341,
#  'rusia': 342,
#  'sapi': 343,
#  'upaya': 344,
#  'mei': 345,
#  'istri': 346,
#  'universitas': 347,
#  'henti': 348,
#  'babi': 349,
#  'februari': 350,
#  'ganjar': 351,
#  'pdip': 352,
#  'lintas': 353,
#  'wartawan': 354,
#  'jaya': 355,
#  'desember': 356,
#  'dewas': 357,
#  'hak': 358,
#  'tolak': 359,
#  'bulu': 360,
#  'rakyat': 361,
#  'manfaat': 362,
#  'pungli': 363,
#  'upa': 364,
#  'batas': 365,
#  'jemaah': 366,
#  'ke-@': 367,
#  'komunikasi': 368,
#  'as': 369,
#  'detikcom': 370,
#  'adil': 371,
#  'jenderal': 372,
#  'mengatasnamakan': 373,
#  'mantan': 374,
#  'juli': 375,
#  'al': 376,
#  'bahaya': 377,
#  'izin': 378,
#  'i': 379,
#  'jam': 380,
#  'simpul': 381,
#  'konsumsi': 382,
#  'kanker': 383,
#  'bandara': 384,
#  'cepat': 385,
#  'sabtu': 386,
#  'halaman': 387,
#  'pagi': 388,
#  'merdeka': 389,
#  'provinsi': 390,
#  'humas': 391,
#  'biaya': 392,
#  'merah': 393,
#  'kenal': 394,
#  'ganggu': 395,
#  'tolong': 396,
#  'tiktok': 397,
#  'teliti': 398,
#  'tewas': 399,
#  'anggap': 400,
#  'go': 401,
#  'komisi': 402,
#  'laut': 403,
#  'hakim': 404,
#  'hilang': 405,
#  'tiru': 406,
#  'minum': 407,
#  'putih': 408,
#  'terbit': 409,
#  'aplikasi': 410,
#  'amerika': 411,
#  'putri': 412,
#  'editor': 413,
#  'imbau': 414,
#  'stroke': 415,
#  'sikat': 416,
#  'menit': 417,
#  'bangsa': 418,
#  'gedung': 419,
#  'bebas': 420,
#  'barang': 421,
#  'larang': 422,
#  'publik': 423,
#  'mahasiswa': 424,
#  'gunung': 425,
#  'urus': 426,
#  'duduk': 427,
#  'bayi': 428,
#  'gaji': 429,
#  'polres': 430,
#  'pokemon': 431,
#  'direktur': 432,
#  'bentang': 433,
#  'sim': 434,
#  'md': 435,
#  'tanggung': 436,
#  'celaka': 437,
#  'awas': 438,
#  'bupati': 439,
#  'catat': 440,
#  'menang': 441,
#  'milu': 442,
#  'link': 443,
#  'guru': 444,
#  'online': 445,
#  'keras': 446,
#  'org': 447,
#  'gigi': 448,
#  'bidang': 449,
#  'sedia': 450,
#  'hewan': 451,
#  'thumbnail': 452,
#  'ukraina': 453,
#  'turnbackhoax': 454,
#  'capai': 455,
#  'iphone': 456,
#  'ruang': 457,
#  'ibadah': 458,
#  'edit': 459,
#  'proyek': 460,
#  'tribunnews': 461,
#  'permen': 462,
#  'november': 463,
#  'pasar': 464,
#  'internasional': 465,
#  'muslim': 466,
#  'febrylian': 467,
#  'percaya': 468,
#  'uu': 469,
#  'alas': 470,
#  'bijak': 471,
#  'pribadi': 472,
#  'h': 473,
#  'kemarin': 474,
#  'ancam': 475,
#  'macet': 476,
#  'tanda': 477,
#  'tol': 478,
#  'usia': 479,
#  'ekonomi': 480,
#  'kumpul': 481,
#  'jabodetabek': 482,
#  'kelompok': 483,
#  'aceh': 484,
#  'rekam': 485,
#  'kapal': 486,
#  'kawasan': 487,
#  'mahfud': 488,
#  'rusak': 489,
#  'derita': 490,
#  'kapolri': 491,
#  'sistem': 492,
#  'tempo': 493,
#  'serah': 494,
#  'status': 495,
#  'ma': 496,
#  'mata': 497,
#  'al-zaytun': 498,
#  'warna': 499,
#  'kunjung': 500,
#  'tuntut': 501,
#  'lingkung': 502,
#  'dagang': 503,
#  'saudara': 504,
#  'istiqlal': 505,
#  'muat': 506,
#  'for': 507,
#  'luka': 508,
#  'hut': 509,
#  'kasih': 510,
#  'alat': 511,
#  'surabaya': 512,
#  'post': 513,
#  'pertamina': 514,
#  'budaya': 515,
#  'kpu': 516,
#  'by': 517,
#  'budi': 518,
#  'lahir': 519,
#  'karno': 520,
#  'laman': 521,
#  'paham': 522,
#  'teman': 523,
#  'selenggara': 524,
#  'ahmad': 525,
#  'ahok': 526,
#  'lawan': 527,
#  'bohong': 528,
#  'daring': 529,
#  'tua': 530,
#  'latih': 531,
#  'info': 532,
#  'wajib': 533,
#  'maaf': 534,
#  'beliau': 535,
#  'oktober': 536,
#  'sunting': 537,
#  'unit': 538,
#  'gl': 539,
#  'goo': 540,
#  'umat': 541,
#  'saudi': 542,
#  'perempuan': 543,
#  'no': 544,
#  'juang': 545,
#  'pantau': 546,
#  'maksud': 547,
#  'australia': 548,
#  'identik': 549,
#  'kampanye': 550,
#  'kelola': 551,
#  'gugat': 552,
#  'ham': 553,
#  'fasilitas': 554,
#  'agung': 555,
#  'bersih': 556,
#  'tembak': 557,
#  'beranta': 558,
#  'an': 559,
#  'depok': 560,
#  'salat': 561,
#  'bumi': 562,
#  'operasi': 563,
#  'waspada': 564,
#  'kotor': 565,
#  'panggil': 566,
#  'virus': 567,
#  'september': 568,
#  'sri': 569,
#  'paksa': 570,
#  'serikat': 571,
#  'tunggu': 572,
#  'tawar': 573,
#  'dokumen': 574,
#  'cek': 575,
#  'persen': 576,
#  'lukas': 577,
#  'istana': 578,
#  'heru': 579,
#  'gabung': 580,
#  'tekan': 581,
#  'penjara': 582,
#  'halal': 583,
#  'syarat': 584,
#  'bekas': 585,
#  'angka': 586,
#  'lindung': 587,
#  'mui': 588,
#  'dengar': 589,
#  'alias': 590,
#  'narkoba': 591,
#  'kanal': 592,
#  'kuasa': 593,
#  'bandung': 594,
#  'timbul': 595,
#  'moga': 596,
#  'sambo': 597,
#  'maju': 598,
#  'this': 599,
#  'lapang': 600,
#  'muda': 601,
#  'pasien': 602,
#  'olah': 603,
#  'puncak': 604,
#  'dampak': 605,
#  'sel': 606,
#  'banding': 607,
#  'perkara': 608,
#  'ponpes': 609,
#  'allah': 610,
#  'sigit': 611,
#  'gerindra': 612,
#  'cerita': 613,
#  'pilpres': 614,
#  'republik': 615,
#  'sambut': 616,
#  'tokoh': 617,
#  'sikap': 618,
#  'janji': 619,
#  'medan': 620,
#  'terbang': 621,
#  'bpjs': 622,
#  'akses': 623,
#  'rapat': 624,
#  'daya': 625,
#  'ramai': 626,
#  'rugi': 627,
#  'lepas': 628,
#  'agus': 629,
#  'akbp': 630,
#  'muhammad': 631,
#  'hujan': 632,
#  'panas': 633,
#  'verifikasi': 634,
#  'triliun': 635,
#  'gratis': 636,
#  'malaysia': 637,
#  'pidato': 638,
#  'agustus': 639,
#  'imbuh': 640,
#  'langkah': 641,
#  'kemudi': 642,
#  'amin': 643,
#  'daging': 644,
#  'listrik': 645,
#  'etik': 646,
#  'bus': 647,
#  'panji': 648,
#  'perang': 649,
#  'suka': 650,
#  'pemprov': 651,
#  'dot': 652,
#  'nya': 653,
#  'e': 654,
#  'oknum': 655,
#  'ali': 656,
#  'jiwa': 657,
#  'aja': 658,
#  'd': 659,
#  'tani': 660,
#  'pintu': 661,
#  'suami': 662,
#  'aju': 663,
#  'aniaya': 664,
#  'https': 665,
#  'perhati': 666,
#  'tangerang': 667,
#  'lidi': 668,
#  'jepang': 669,
#  'posisi': 670,
#  'tarik': 671,
#  'reog': 672,
#  'ahli': 673,
#  'tenaga': 674,
#  'plate': 675,
#  'udara': 676,
#  'durasi': 677,
#  'facebookarchive': 678,
#  'kombes': 679,
#  'cuplik': 680,
#  'jembatan': 681,
#  'israel': 682,
#  'pungkas': 683,
#  'lari': 684,
#  'cegah': 685,
#  'sumatera': 686,
#  'usul': 687,
#  'ii': 688,
#  'hutan': 689,
#  'luas': 690,
#  'si': 691,
#  'dprd': 692,
#  'mas': 693,
#  'abdul': 694,
#  'komentar': 695,
#  'senjata': 696,
#  'website': 697,
#  'fitnah': 698,
#  'bocor': 699,
#  'rupiah': 700,
#  'kapolres': 701,
#  'total': 702,
#  'channel': 703,
#  'gereja': 704,
#  'tusuk': 705,
#  'modus': 706,
#  'sambung': 707,
#  'rp@': 708,
#  'tonton': 709,
#  'tiket': 710,
#  'dewan': 711,
#  'grup': 712,
#  'aktif': 713,
#  'it': 714,
#  'batu': 715,
#  't': 716,
#  'piala': 717,
#  'majelis': 718,
#  'hadiah': 719,
#  'johnny': 720,
#  'terjemah': 721,
#  'tumpang': 722,
#  'with': 723,
#  'wali': 724,
#  'aset': 725,
#  'misleading': 726,
#  'api': 727,
#  'pers': 728,
#  'tv': 729,
#  'pasu': 730,
#  'jasa': 731,
#  'minyak': 732,
#  'sulit': 733,
#  'mario': 734,
#  'kartu': 735,
#  'ratus': 736,
#  'muhammadiyah': 737,
#  'alam': 738,
#  'said': 739,
#  'nila': 740,
#  'hapus': 741,
#  'truk': 742,
#  'traveloka': 743,
#  'juru': 744,
#  'liputan@': 745,
#  'hormat': 746,
#  'ulama': 747,
#  'bristle': 748,
#  'ayat': 749,
#  'inisial': 750,
#  'sidik': 751,
#  'pulau': 752,
#  'tabrak': 753,
#  'hitung': 754,
#  'sang': 755,
#  'massa': 756,
#  'doa': 757,
#  'cipta': 758,
#  'picu': 759,
#  'gbk': 760,
#  'produksi': 761,
#  'jalur': 762,
#  'bikin': 763,
#  'besok': 764,
#  'lurah': 765,
#  'evaluasi': 766,
#  'puluh': 767,
#  'malang': 768,
#  'tes': 769,
#  'cnn': 770,
#  'logo': 771,
#  'sisi': 772,
#  'ajak': 773,
#  'taut': 774,
#  'gera': 775,
#  'ruf': 776,
#  'kuas': 777,
#  'anti': 778,
#  'asing': 779,
#  'jantung': 780,
#  'n': 781,
#  'pulang': 782,
#  'b': 783,
#  'stadion': 784,
#  'salur': 785,
#  'dwi': 786,
#  'sangkut': 787,
#  'tahap': 788,
#  'ananda': 789,
#  'brimob': 790,
#  'megawati': 791,
#  'rangka': 792,
#  'bal': 793,
#  'periode': 794,
#  'vonis': 795,
#  'alir': 796,
#  'koordinasi': 797,
#  'be': 798,
#  'hitam': 799,
#  'kader': 800,
#  'gerak': 801,
#  'ledak': 802,
#  'wajah': 803,
#  'leceh': 804,
#  'inggris': 805,
#  'that': 806,
#  'bilang': 807,
#  'otak': 808,
#  'desmond': 809,
#  'bts': 810,
#  'sanksi': 811,
#  'pecah': 812,
#  'from': 813,
#  'banjir': 814,
#  'kamar': 815,
#  'plus': 816,
#  'iii': 817,
#  'jl': 818,
#  'potensi': 819,
#  'telepon': 820,
#  'sita': 821,
#  'twitterarchive': 822,
#  'aktivitas': 823,
#  'pandemi': 824,
#  'perkosa': 825,
#  'siang': 826,
#  'rt': 827,
#  'bendera': 828,
#  'bmkg': 829,
#  'kominfo': 830,
#  'kaki': 831,
#  'ponorogo': 832,
#  'stasiun': 833,
#  'komunitas': 834,
#  'gumilang': 835,
#  'davao': 836,
#  'twibbon': 837,
#  'pengaruh': 838,
#  'khairunnisa': 839,
#  'belah': 840,
#  'damping': 841,
#  'kereta': 842,
#  'militer': 843,
#  'tayang': 844,
#  'teknologi': 845,
#  'banten': 846,
#  'uin': 847,
#  'survei': 848,
#  'adu': 849,
#  'bongkar': 850,
#  'at': 851,
#  'g': 852,
#  'tentara': 853,
#  'kjri': 854,
#  'argentina': 855,
#  'pikir': 856,
#  'bhayangkara': 857,
#  'bisnis': 858,
#  'siti': 859,
#  'keluh': 860,
#  'anggar': 861,
#  'singkat': 862,
#  'sejarah': 863,
#  'mk': 864,
#  'baju': 865,
#  'putra': 866,
#  'damai': 867,
#  'memposting': 868,
#  'timnas': 869,
#  'iklan': 870,
#  'kampung': 871,
#  'simpang': 872,
#  'translate': 873,
#  'gibran': 874,
#  'infrastruktur': 875,
#  'berangkat': 876,
#  'habis': 877,
#  'transjakarta': 878,
#  'fafhh': 879,
#  'medis': 880,
#  'hindar': 881,
#  'david': 882,
#  'cinta': 883,
#  'sembuh': 884,
#  'afp': 885,
#  'ferdy': 886,
#  'raja': 887,
#  'area': 888,
#  'sulawesi': 889,
#  'sadar': 890,
#  'organisasi': 891,
#  'nikah': 892,
#  'aparat': 893,
#  'putar': 894,
#  'malu': 895,
#  'meter': 896,
#  'kunci': 897,
#  'rawan': 898,
#  'timbang': 899,
#  'game': 900,
#  'bumn': 901,
#  'cnnindonesia': 902,
#  'palestina': 903,
#  'puan': 904,
#  'situasi': 905,
#  'titik': 906,
#  'pesantren': 907,
#  'unsur': 908,
#  'siswa': 909,
#  'terap': 910,
#  'perangkat': 911,
#  'sertifikat': 912,
#  'pp': 913,
#  'km': 914,
#  'unjung': 915,
#  'vaksinasi': 916,
#  'gas': 917,
#  'zat': 918,
#  'suap': 919,
#  'perihal': 920,
#  'cabut': 921,
#  'lagu': 922,
#  'jaksel': 923,
#  'pandang': 924,
#  'sore': 925,
#  'sampah': 926,
#  'bencana': 927,
#  'out': 928,
#  'pemuda': 929,
#  'tata': 930,
#  'sekretaris': 931,
#  'ponsel': 932,
#  'luncur': 933,
#  'ginjal': 934,
#  'cantum': 935,
#  'enembe': 936,
#  'demo': 937,
#  'contoh': 938,
#  'novel': 939,
#  'yogyakarta': 940,
#  'capres': 941,
#  'kelas': 942,
#  'keliru': 943,
#  'digital': 944,
#  'rs': 945,
#  'jamin': 946,
#  'tanam': 947,
#  'pandeglang': 948,
#  'ayah': 949,
#  'sifat': 950,
#  'jarum': 951,
#  'usut': 952,
#  'satgas': 953,
#  'dorong': 954,
#  'rilis': 955,
#  'pn': 956,
#  'apple': 957,
#  'karya': 958,
#  'peran': 959,
#  'film': 960,
#  'emas': 961,
#  'timwas': 962,
#  'rusa': 963,
#  'lantar': 964,
#  'first': 965,
#  'jelang': 966,
#  'untung': 967,
#  'takut': 968,
#  'huni': 969,
#  'kalimantan': 970,
#  'momen': 971,
#  'praktik': 972,
#  'was': 973,
#  'dandy': 974,
#  'kode': 975,
#  'bina': 976,
#  'mulyani': 977,
#  'padat': 978,
#  'khawatir': 979,
#  'jaring': 980,
#  'normal': 981,
#  'cuaca': 982,
#  'kualitas': 983,
#  'umur': 984,
#  'fifa': 985,
#  'rusuh': 986,
#  'ukur': 987,
#  'protes': 988,
#  'antaranews': 989,
#  'jari': 990,
#  'c': 991,
#  'biar': 992,
#  'sipil': 993,
#  'laki': 994,
#  'papar': 995,
#  'gula': 996,
#  'abu': 997,
#  'jabar': 998,
#  'heboh': 999,
#  ...}

# %%
#Code below is adapted from: https://www.tensorflow.org/tutorials/text/word_embeddings#retrieve_the_trained_word_embeddings_and_save_them_to_disk
import io

# Create output writers
out_v = io.open("embedding_vectors.tsv", "w", encoding="utf-8")
out_m = io.open("embedding_metadata.tsv", "w", encoding="utf-8")

# Write embedding vectors and words to file
for num, word in enumerate(vocab):
  if num == 0: 
     continue # skip padding token
  vec = wgt[num]
  out_m.write(word + "\n") # write words to file
  out_v.write("\t".join([str(x) for x in vec]) + "\n") # write corresponding word vector to file
out_v.close()
out_m.close()

# Download files locally to upload to Embedding Projector
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download("embedding_vectors.tsv")
  files.download("embedding_metadata.tsv")
